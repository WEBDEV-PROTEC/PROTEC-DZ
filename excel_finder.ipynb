# %%
from odoo import models
from odoo.tools import config
import json
import csv
import pandas as pd

# %%
group_data_hyphens = {
  "ART": {
    "ART-A": [
      {
        "New Ref Code": "ART-ARC3000H-03-FW2(868)"
      },
      {
        "New Ref Code": "ART-ARC3000H-03-GW2(868)"
      },
      {
        "New Ref Code": "ART-ARC3000H-03-W2(868)"
      }
    ]
  },
  "CSS": {
    "CSS-C": [
      {
        "New Ref Code": "CSS-CSM"
      }
    ],
    "CSS-T": [
      {
        "New Ref Code": "CSS-TPCN"
      }
    ]
  },
  "DAE": {
    "DAE-C": [
      {
        "New Ref Code": "DAE-CBS5210-H-CYN"
      },
      {
        "New Ref Code": "DAE-CBS5210-H-CYP"
      },
      {
        "New Ref Code": "DAE-CBS5210-V-CYP"
      },
      {
        "New Ref Code": "DAE-CBS5210-V-CYN"
      },
      {
        "New Ref Code": "DAE-CDR8213-GFW"
      }
    ]
  },
  "DDR": {
    "DDR-C": [
      {
        "New Ref Code": "DDR-C300S16G32"
      },
      {
        "New Ref Code": "DDR-C300S4G26"
      },
      {
        "New Ref Code": "DDR-C300U8G26"
      },
      {
        "New Ref Code": "DDR-C300S8G26"
      },
      {
        "New Ref Code": "DDR-C300U16G26"
      },
      {
        "New Ref Code": "DDR-C300U16G32"
      },
      {
        "New Ref Code": "DDR-C300U8G32"
      },
      {
        "New Ref Code": "DDR-C300S8G32"
      },
      {
        "New Ref Code": "DDR-C160S4G16"
      },
      {
        "New Ref Code": "DDR-C160S8G16"
      },
      {
        "New Ref Code": "DDR-C160U8G16"
      }
    ]
  },
  "DHL": {
    "DHL-F": [
      {
        "New Ref Code": "DHL-FJ"
      }
    ]
  },
  "Ex": {
    "Ex-C-": [
      {
        "New Ref Code": "Ex-C-Base Channel"
      },
      {
        "New Ref Code": "Ex-C-Vehicle Module"
      },
      {
        "New Ref Code": "Ex-C-Base Module"
      },
      {
        "New Ref Code": "Ex-C-Dashboard Module"
      },
      {
        "New Ref Code": "Ex-C-Structuring Module"
      },
      {
        "New Ref Code": "Ex-C-Structuring Channel"
      },
      {
        "New Ref Code": "Ex-C-Vehicle Tactics Module"
      },
      {
        "New Ref Code": "Ex-C-Vehicle Channel"
      }
    ],
    "Ex-T-": [
      {
        "New Ref Code": "Ex-T-Signal Control Module"
      },
      {
        "New Ref Code": "Ex-T-Violation Review Module"
      },
      {
        "New Ref Code": "Ex-T-Traffice Event Module"
      },
      {
        "New Ref Code": "Ex-T-Vehicle Module"
      },
      {
        "New Ref Code": "Ex-T-Violation Detection Module"
      },
      {
        "New Ref Code": "Ex-T-Signal Control Channel"
      }
    ]
  },
  "F2C": {
    "F2C-L": [
      {
        "New Ref Code": "F2C-LED"
      }
    ],
    "F2C-P": [
      {
        "New Ref Code": "F2C-PV"
      }
    ]
  },
  "F4C": {
    "F4C-L": [
      {
        "New Ref Code": "F4C-LED"
      }
    ],
    "F4C-P": [
      {
        "New Ref Code": "F4C-PV"
      }
    ]
  },
  "HAC": {
    "HAC-B": [
      {
        "New Ref Code": "HAC-B3A51P-Z"
      },
      {
        "New Ref Code": "HAC-B2A51P"
      },
      {
        "New Ref Code": "HAC-B1A51P"
      },
      {
        "New Ref Code": "HAC-B4A21P-VF"
      },
      {
        "New Ref Code": "HAC-B2A21P"
      },
      {
        "New Ref Code": "HAC-B1A21P"
      }
    ],
    "HAC-D": [
      {
        "New Ref Code": "HAC-D3A51P-Z"
      },
      {
        "New Ref Code": "HAC-D1A51P"
      },
      {
        "New Ref Code": "HAC-D3A21P-Z"
      },
      {
        "New Ref Code": "HAC-D3A21P-VF"
      },
      {
        "New Ref Code": "HAC-D1A21P"
      }
    ],
    "HAC-E": [
      {
        "New Ref Code": "HAC-EW2501P"
      }
    ],
    "HAC-H": [
      {
        "New Ref Code": "HAC-HFW2501TUP-A"
      },
      {
        "New Ref Code": "HAC-HDBW2501FP-A"
      },
      {
        "New Ref Code": "HAC-HDW2501TQP-A"
      },
      {
        "New Ref Code": "HAC-HFW1500RP-Z-IRE6-A-DP"
      },
      {
        "New Ref Code": "HAC-HDW1500TP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDW1500TP-Z"
      },
      {
        "New Ref Code": "HAC-HDW1500TMQP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDW1500TMQP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TMQP-Z"
      },
      {
        "New Ref Code": "HAC-HDBW2802RAP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDBW2802RAP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDBW2501EAP-A"
      },
      {
        "New Ref Code": "HAC-HDBW2501EAP-A"
      },
      {
        "New Ref Code": "HAC-HDBW2501RAP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDBW2501RAP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDBW2501RAP-Z-A-POC"
      },
      {
        "New Ref Code": "HAC-HF3101EP"
      },
      {
        "New Ref Code": "HAC-HF3805GP"
      },
      {
        "New Ref Code": "HAC-HFW3802EP-Z-VP"
      },
      {
        "New Ref Code": "HAC-HFW3802EP-ZH-VP"
      },
      {
        "New Ref Code": "HAC-HDBW3802EP-ZH"
      },
      {
        "New Ref Code": "HAC-HDBW3802EP-Z"
      },
      {
        "New Ref Code": "HAC-HFW2509TUP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW2509TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW2509TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW2509TLMP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW2501TUP-Z-A"
      },
      {
        "New Ref Code": "HAC-HFW2501TUP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDBW2501RP-Z"
      },
      {
        "New Ref Code": "HAC-HDBW2501RP-Z-DP"
      },
      {
        "New Ref Code": "HAC-HDW2501TP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDW2501TP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDW2501TMQP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDW2501TMQP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HFW2501EP-A"
      },
      {
        "New Ref Code": "HAC-HFW2501CMP-A"
      },
      {
        "New Ref Code": "HAC-HDBW2501EP"
      },
      {
        "New Ref Code": "HAC-HDW2501TMQP-A"
      },
      {
        "New Ref Code": "HAC-HDW2501TLMQP-A"
      },
      {
        "New Ref Code": "HAC-HFW2249TUP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW2249TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW2249TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW2241TUP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDBW2241RAP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDW2241TMQP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDW2241TMQP-A"
      },
      {
        "New Ref Code": "HAC-HDW2241TLMP-A"
      },
      {
        "New Ref Code": "HAC-HDW1809TLMP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1809TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1809TLMP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1809TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1239TMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1239TP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDBW1239RAP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1509TP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1509TP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1509TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1509TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1509TMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1801THP-I8"
      },
      {
        "New Ref Code": "HAC-HFW1801THP-I8"
      },
      {
        "New Ref Code": "HAC-HFW1801THP-I8"
      },
      {
        "New Ref Code": "HAC-HFW1801THP-I4"
      },
      {
        "New Ref Code": "HAC-HFW1801THP-I4"
      },
      {
        "New Ref Code": "HAC-HFW1801CP"
      },
      {
        "New Ref Code": "HAC-HFW1801CP"
      },
      {
        "New Ref Code": "HAC-HFW1801CP-A"
      },
      {
        "New Ref Code": "HAC-HFW1801CP-A"
      },
      {
        "New Ref Code": "HAC-HFW1801TP"
      },
      {
        "New Ref Code": "HAC-HFW1801TP"
      },
      {
        "New Ref Code": "HAC-HFW1801TP-A"
      },
      {
        "New Ref Code": "HAC-HFW1801TP-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TLMP"
      },
      {
        "New Ref Code": "HAC-HDW1801TLMP"
      },
      {
        "New Ref Code": "HAC-HDW1801TLMP-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TLMP-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TLQP"
      },
      {
        "New Ref Code": "HAC-HDW1801TLQP"
      },
      {
        "New Ref Code": "HAC-HDW1801TLQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TLQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TP"
      },
      {
        "New Ref Code": "HAC-HDW1801TP"
      },
      {
        "New Ref Code": "HAC-HDW1801TP"
      },
      {
        "New Ref Code": "HAC-HDW1801TP-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TP-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TP-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TQP-A"
      },
      {
        "New Ref Code": "HAC-HFW1801TMP-I8"
      },
      {
        "New Ref Code": "HAC-HFW1801TMP-I8"
      },
      {
        "New Ref Code": "HAC-HFW1801TMP-I8"
      },
      {
        "New Ref Code": "HAC-HDBW1801EAP"
      },
      {
        "New Ref Code": "HAC-HDBW1801EAP-A"
      },
      {
        "New Ref Code": "HAC-HDBW1801RAP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDBW1801RAP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDW1801TP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDW1801TMQP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TMQP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HFW1801RP-Z-A"
      },
      {
        "New Ref Code": "HAC-HFW1801RP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDW1209TLQP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1209CLQP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1209CLQP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1209TQP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1209CLQP-LED"
      },
      {
        "New Ref Code": "HAC-HDW1209CLQP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1209TLMP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1209TLMP-LED"
      },
      {
        "New Ref Code": "HAC-HDW1209TLQP-LED"
      },
      {
        "New Ref Code": "HAC-HDW1209TLQP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1209CP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1209CMP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1209CP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1209CP-LED"
      },
      {
        "New Ref Code": "HAC-HDW1801TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1801TP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1801TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1801TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1801CMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1801CMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1500CLP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1500CLP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1500TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1500TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1500CLQP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1500CLQP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1500CMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1500CMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1200TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1200TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1200TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1200TLMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1200TP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1200TP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1200CLP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1200CLP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1200CMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1200CMP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1200CLQP-IL-A"
      },
      {
        "New Ref Code": "HAC-HDW1200CLQP-IL-A"
      },
      {
        "New Ref Code": "HAC-HFW1200TP"
      },
      {
        "New Ref Code": "HAC-HDW1200TRQP"
      },
      {
        "New Ref Code": "HAC-HDW1200TRQP-A"
      },
      {
        "New Ref Code": "HAC-HFW1200RP-Z-A"
      },
      {
        "New Ref Code": "HAC-HFW1800TP-A"
      },
      {
        "New Ref Code": "HAC-HFW1800TP"
      },
      {
        "New Ref Code": "HAC-HDW1800TLP-A"
      },
      {
        "New Ref Code": "HAC-HDW1800RP"
      },
      {
        "New Ref Code": "HAC-HFW1509TUP-Z-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TUP-Z-A-LED-DP"
      },
      {
        "New Ref Code": "HAC-HDW1509TP-Z-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1509TP-Z-A-LED-DP"
      },
      {
        "New Ref Code": "HAC-HFW1509MHP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TMP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TLMP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TLMP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TLMP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TLMP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509TP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509CP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509CP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1509CP-LED"
      },
      {
        "New Ref Code": "HAC-HDW1509TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1509TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1509TP-LED"
      },
      {
        "New Ref Code": "HAC-HDW1509TP-LED"
      },
      {
        "New Ref Code": "HAC-HDW1509TLQP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1509TLQP-LED"
      },
      {
        "New Ref Code": "HAC-HDW1509TLQP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1500RP-Z-IRE6-A"
      },
      {
        "New Ref Code": "HAC-HFW1500RP-Z-IRE6"
      },
      {
        "New Ref Code": "HAC-HDBW1500RP-Z"
      },
      {
        "New Ref Code": "HAC-HDW1500TP-Z-A"
      },
      {
        "New Ref Code": "HAC-HFW1500DP"
      },
      {
        "New Ref Code": "HAC-HFW1500THP-I4"
      },
      {
        "New Ref Code": "HAC-HFW1500THP-I4"
      },
      {
        "New Ref Code": "HAC-HFW1500THP-I8"
      },
      {
        "New Ref Code": "HAC-HFW1500THP-I8"
      },
      {
        "New Ref Code": "HAC-HFW1500THP-I8"
      },
      {
        "New Ref Code": "HAC-HFW1500TLP-A"
      },
      {
        "New Ref Code": "HAC-HFW1500TLP"
      },
      {
        "New Ref Code": "HAC-HFW1500TP-A"
      },
      {
        "New Ref Code": "HAC-HFW1500TP-A"
      },
      {
        "New Ref Code": "HAC-HFW1500TP"
      },
      {
        "New Ref Code": "HAC-HFW1500CMP-A"
      },
      {
        "New Ref Code": "HAC-HFW1500CMP-A"
      },
      {
        "New Ref Code": "HAC-HFW1500CMP"
      },
      {
        "New Ref Code": "HAC-HFW1500CMP"
      },
      {
        "New Ref Code": "HAC-HFW1500CP-A"
      },
      {
        "New Ref Code": "HAC-HFW1500CP-A"
      },
      {
        "New Ref Code": "HAC-HFW1500CP"
      },
      {
        "New Ref Code": "HAC-HFW1500CP"
      },
      {
        "New Ref Code": "HAC-HDBW1500EP"
      },
      {
        "New Ref Code": "HAC-HDBW1500EP"
      },
      {
        "New Ref Code": "HAC-HDW1500TMQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TMQP"
      },
      {
        "New Ref Code": "HAC-HDW1500TQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TQP"
      },
      {
        "New Ref Code": "HAC-HDW1500TLMQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TLMQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TLMQP"
      },
      {
        "New Ref Code": "HAC-HDW1500TLMQP"
      },
      {
        "New Ref Code": "HAC-HDW1500TLMP-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TLMP"
      },
      {
        "New Ref Code": "HAC-HDW1500TLQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TRQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TRQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1500TRQP"
      },
      {
        "New Ref Code": "HAC-HDW1500TRQP"
      },
      {
        "New Ref Code": "HAC-HFW1239TUP-Z-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239TUP-Z-A-LED-DP"
      },
      {
        "New Ref Code": "HAC-HDW1239TP-Z-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239TMP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239TLMP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239TLMP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239TLMP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239TP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239TP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1239CP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1239TP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1239TP-LED"
      },
      {
        "New Ref Code": "HAC-HDW1239TLQP-A-LED"
      },
      {
        "New Ref Code": "HAC-HDW1239TLQP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1231RP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HFW1231RP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDBW1231RAP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDBW1231RAP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDW1231TMQP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDW1231TMQP-Z-A"
      },
      {
        "New Ref Code": "HAC-HDW1231TP-Z-A-DP"
      },
      {
        "New Ref Code": "HAC-HDW1231TP-Z-A"
      },
      {
        "New Ref Code": "HAC-HFW1231TMP-I8-A"
      },
      {
        "New Ref Code": "HAC-HFW1231TLMP-I6-A"
      },
      {
        "New Ref Code": "HAC-HFW1231TLMP-I6"
      },
      {
        "New Ref Code": "HAC-HFW1231CMP-A"
      },
      {
        "New Ref Code": "HAC-HFW1231CMP"
      },
      {
        "New Ref Code": "HAC-HFW1231CP-A"
      },
      {
        "New Ref Code": "HAC-HDBW1231EAP-A"
      },
      {
        "New Ref Code": "HAC-HDW1231TMQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1231TQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1231TLMQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1231TLMQP"
      },
      {
        "New Ref Code": "HAC-HDW1231TLMP-A"
      },
      {
        "New Ref Code": "HAC-HDW1231TLMP"
      },
      {
        "New Ref Code": "HAC-HDW1231TRQP-A"
      },
      {
        "New Ref Code": "HAC-HDW1231GP-A"
      },
      {
        "New Ref Code": "HAC-HDW1209TLQP-LED"
      },
      {
        "New Ref Code": "HAC-HFW1200TP"
      },
      {
        "New Ref Code": "HAC-HFW1500RP-Z-IRE6-A-POC"
      },
      {
        "New Ref Code": "HAC-HDW1500TMQP-Z-A-POC"
      },
      {
        "New Ref Code": "HAC-HDW1500TP-Z-A-POC"
      },
      {
        "New Ref Code": "HAC-HFW1500THP-I8-A-POC"
      },
      {
        "New Ref Code": "HAC-HFW1500CMP-A-POC"
      },
      {
        "New Ref Code": "HAC-HDW1500TMQP-A-POC"
      },
      {
        "New Ref Code": "HAC-HDW1500TQP-A-POC"
      },
      {
        "New Ref Code": "HAC-HDW1500TLMQP-A-POC"
      },
      {
        "New Ref Code": "HAC-HUM3200AP"
      },
      {
        "New Ref Code": "HAC-HUM3201BP-B"
      },
      {
        "New Ref Code": "HAC-HUM3201BP-P"
      },
      {
        "New Ref Code": "HAC-HDBW3200FP"
      },
      {
        "New Ref Code": "HAC-HDW3200GP"
      },
      {
        "New Ref Code": "HAC-HDW3200LP"
      },
      {
        "New Ref Code": "HAC-HMW3200P"
      },
      {
        "New Ref Code": "HAC-HMW3200DP-H"
      },
      {
        "New Ref Code": "HAC-HMW3200LP"
      },
      {
        "New Ref Code": "HAC-HMW3200LP-FR-BUS"
      },
      {
        "New Ref Code": "HAC-HDBW3200FP-M"
      },
      {
        "New Ref Code": "HAC-HDW3200GP-M"
      },
      {
        "New Ref Code": "HAC-HDBW2241FP-M-A"
      }
    ],
    "HAC-M": [
      {
        "New Ref Code": "HAC-ME1239TQP-A-PV"
      },
      {
        "New Ref Code": "HAC-ME1509HP-A-PV"
      },
      {
        "New Ref Code": "HAC-ME1509THP-A-PV"
      },
      {
        "New Ref Code": "HAC-ME1509TQP-A-PV"
      },
      {
        "New Ref Code": "HAC-ME1809HP-A-PV"
      },
      {
        "New Ref Code": "HAC-ME1809HP-A-PV"
      },
      {
        "New Ref Code": "HAC-ME1809TQP-A-PV"
      },
      {
        "New Ref Code": "HAC-ME1809THP-A-PV"
      },
      {
        "New Ref Code": "HAC-ME1809THP-A-PV"
      },
      {
        "New Ref Code": "HAC-ME1800BP-L"
      },
      {
        "New Ref Code": "HAC-ME1500DP-LS"
      },
      {
        "New Ref Code": "HAC-ME1500BP-LS"
      },
      {
        "New Ref Code": "HAC-ME1500EQP-LS"
      },
      {
        "New Ref Code": "HAC-ME1500BP-L"
      },
      {
        "New Ref Code": "HAC-ME1500EQP-L"
      },
      {
        "New Ref Code": "HAC-ME1200DP-LS"
      },
      {
        "New Ref Code": "HAC-ME1200BP-LS"
      },
      {
        "New Ref Code": "HAC-ME1200EQP-LS"
      },
      {
        "New Ref Code": "HAC-ME1200BP-L"
      },
      {
        "New Ref Code": "HAC-ME1200EQP-L"
      }
    ],
    "HAC-P": [
      {
        "New Ref Code": "HAC-PFW3601P-A180"
      },
      {
        "New Ref Code": "HAC-PFW3601P-A180-AC24V"
      }
    ],
    "HAC-T": [
      {
        "New Ref Code": "HAC-T3A51P-Z"
      },
      {
        "New Ref Code": "HAC-T2A51P"
      },
      {
        "New Ref Code": "HAC-T1A51P"
      },
      {
        "New Ref Code": "HAC-T3A21P-Z"
      },
      {
        "New Ref Code": "HAC-T3A21P-VF"
      },
      {
        "New Ref Code": "HAC-T2A21P"
      },
      {
        "New Ref Code": "HAC-T1A21P"
      }
    ]
  },
  "HTI": {
    "HTI-U": [
      {
        "New Ref Code": "HTI-UC325"
      }
    ]
  },
  "HY": {
    "HY-10": [
      {
        "New Ref Code": "HY-1025"
      },
      {
        "New Ref Code": "HY-1022"
      }
    ],
    "HY-12": [
      {
        "New Ref Code": "HY-1200"
      },
      {
        "New Ref Code": "HY-1210"
      }
    ],
    "HY-13": [
      {
        "New Ref Code": "HY-1330"
      },
      {
        "New Ref Code": "HY-1301"
      },
      {
        "New Ref Code": "HY-1310"
      }
    ],
    "HY-14": [
      {
        "New Ref Code": "HY-1400"
      },
      {
        "New Ref Code": "HY-1410"
      },
      {
        "New Ref Code": "HY-1410C"
      },
      {
        "New Ref Code": "HY-1410E"
      },
      {
        "New Ref Code": "HY-1420"
      },
      {
        "New Ref Code": "HY-1431"
      }
    ],
    "HY-15": [
      {
        "New Ref Code": "HY-1500"
      }
    ],
    "HY-17": [
      {
        "New Ref Code": "HY-1711"
      }
    ],
    "HY-AN": [
      {
        "New Ref Code": "HY-ANDZ"
      }
    ],
    "HY-AS": [
      {
        "New Ref Code": "HY-ASD420B"
      }
    ],
    "HY-C1": [
      {
        "New Ref Code": "HY-C102-4"
      },
      {
        "New Ref Code": "HY-C131"
      },
      {
        "New Ref Code": "HY-C121"
      },
      {
        "New Ref Code": "HY-C151"
      }
    ],
    "HY-FT": [
      {
        "New Ref Code": "HY-FT121LDP"
      },
      {
        "New Ref Code": "HY-FT121LDN"
      },
      {
        "New Ref Code": "HY-FT431LDP"
      }
    ],
    "HY-M1": [
      {
        "New Ref Code": "HY-M1"
      }
    ],
    "HY-MK": [
      {
        "New Ref Code": "HY-MKDZ2"
      }
    ],
    "HY-SA": [
      {
        "New Ref Code": "HY-SAV849HAP-ET"
      },
      {
        "New Ref Code": "HY-SAV849HAN-ET"
      },
      {
        "New Ref Code": "HY-SAV849HAN-E"
      },
      {
        "New Ref Code": "HY-SA21A-W2"
      },
      {
        "New Ref Code": "HY-SA21A-W2(868)"
      }
    ],
    "HY-SG": [
      {
        "New Ref Code": "HY-SGDZ"
      }
    ],
    "HY-TC": [
      {
        "New Ref Code": "HY-TCDZ"
      }
    ]
  },
  "ICS1": {
    "ICS1-": [
      {
        "New Ref Code": "ICS1-W2(868)"
      }
    ]
  },
  "IPC": {
    "IPC-E": [
      {
        "New Ref Code": "IPC-EW5541P-AS"
      },
      {
        "New Ref Code": "IPC-EBW8842-AS"
      },
      {
        "New Ref Code": "IPC-EBW8630P"
      }
    ],
    "IPC-H": [
      {
        "New Ref Code": "IPC-HDBW4241E-AS"
      },
      {
        "New Ref Code": "IPC-HDBW4441E-AS"
      },
      {
        "New Ref Code": "IPC-HDBW4841E-AS"
      },
      {
        "New Ref Code": "IPC-HFW5842DK1-Z-5G"
      },
      {
        "New Ref Code": "IPC-HFW5842DK1-Z4-5G"
      },
      {
        "New Ref Code": "IPC-HDBW5541R-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5442T-ZE"
      },
      {
        "New Ref Code": "IPC-HFW5442E-ZE"
      },
      {
        "New Ref Code": "IPC-HDBW5842E-ZE"
      },
      {
        "New Ref Code": "IPC-HFW7442H-Z-X"
      },
      {
        "New Ref Code": "IPC-HDW5842TM-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5442TM-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5241E-Z12E"
      },
      {
        "New Ref Code": "IPC-HDBW7842E1-Z-X"
      },
      {
        "New Ref Code": "IPC-HDW5241TMP-AS-LED"
      },
      {
        "New Ref Code": "IPC-HDW5241TMP-AS-LED"
      },
      {
        "New Ref Code": "IPC-HDW5241TM-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5241E-Z5E"
      },
      {
        "New Ref Code": "IPC-HFW5241E-ZE"
      },
      {
        "New Ref Code": "IPC-HDBW5241E-Z5E"
      },
      {
        "New Ref Code": "IPC-HDBW5241E-ZE"
      },
      {
        "New Ref Code": "IPC-HDW5241T-ZE"
      },
      {
        "New Ref Code": "IPC-HF5241F-ZE"
      },
      {
        "New Ref Code": "IPC-HFW5241E-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5241E-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5241E-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5241R-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5241R-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5241R-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5241T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5241T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5241T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5241T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5241T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5241T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5241T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5241T-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5241TM-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5241TM-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5442TMP-AS-LED"
      },
      {
        "New Ref Code": "IPC-HFW5449T-ASE-LED"
      },
      {
        "New Ref Code": "IPC-HFW5449T1-ZE-LED"
      },
      {
        "New Ref Code": "IPC-HDBW5449R1-ZE-LED"
      },
      {
        "New Ref Code": "IPC-HDBW5442H-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW5442H-Z4HE"
      },
      {
        "New Ref Code": "IPC-HFW5442H-ZHE"
      },
      {
        "New Ref Code": "IPC-HDBW5442H-Z4HE"
      },
      {
        "New Ref Code": "IPC-HDBW5442H-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW5442H-Z4HE"
      },
      {
        "New Ref Code": "IPC-HFW5442H-ZHE"
      },
      {
        "New Ref Code": "IPC-HDBW5442E-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW5442T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5442T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5442T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5442T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5442T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5442T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5442E-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5442E-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5442E-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5442R-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5442R-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5442R-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5442TM-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5442TM-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5442E-Z4E"
      },
      {
        "New Ref Code": "IPC-HDBW5442E-ZE"
      },
      {
        "New Ref Code": "IPC-HFW5442E-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW5442E-Z4E"
      },
      {
        "New Ref Code": "IPC-HF5442F-ZE"
      },
      {
        "New Ref Code": "IPC-HDBW5442H-Z4HE"
      },
      {
        "New Ref Code": "IPC-HDW5541H-ASE-PV"
      },
      {
        "New Ref Code": "IPC-HDW5541TM-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5541E-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW5541E-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW5541E-Z5E"
      },
      {
        "New Ref Code": "IPC-HFW5541E-ZE"
      },
      {
        "New Ref Code": "IPC-HDBW5541E-Z5E"
      },
      {
        "New Ref Code": "IPC-HDBW5541E-ZE"
      },
      {
        "New Ref Code": "IPC-HDW5541T-ZE"
      },
      {
        "New Ref Code": "IPC-HF5541F-ZE"
      },
      {
        "New Ref Code": "IPC-HFW5541E-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5541E-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5541E-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5541R-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5541R-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5541T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5541T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5541T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5541T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5541T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5541T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5541T-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5541TM-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5541TM-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5842E-ZE-S2"
      },
      {
        "New Ref Code": "IPC-HFW5842E-Z4E-S2"
      },
      {
        "New Ref Code": "IPC-HF5842F-ZE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842R-ASE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842R-ASE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842R-ASE-S2"
      },
      {
        "New Ref Code": "IPC-HDW5842TM-SE-S2"
      },
      {
        "New Ref Code": "IPC-HDW5842TM-SE-S2"
      },
      {
        "New Ref Code": "IPC-HDW5842TM-SE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-ZHE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-ZHE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-Z4HE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-Z4HE-S2"
      },
      {
        "New Ref Code": "IPC-HFW5849T1-ASE-LED"
      },
      {
        "New Ref Code": "IPC-HDW5842TM-SE-S2"
      },
      {
        "New Ref Code": "IPC-HDW5842TM-SE-S2"
      },
      {
        "New Ref Code": "IPC-HDW5842TM-SE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-ZHE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-ZHE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-Z4HE-S2"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-Z4HE-S2"
      },
      {
        "New Ref Code": "IPC-HFW5842H-Z4HE"
      },
      {
        "New Ref Code": "IPC-HFW5842H-ZHE"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-Z4HE"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW5842H-Z4HE"
      },
      {
        "New Ref Code": "IPC-HFW5842H-ZHE"
      },
      {
        "New Ref Code": "IPC-HDBW5842E-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW5842T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5842T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5842T-SE"
      },
      {
        "New Ref Code": "IPC-HFW5842T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5842T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5842T-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5842E-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5842E-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5842E-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5842R-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5842R-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5842R-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5842TM-ASE"
      },
      {
        "New Ref Code": "IPC-HDW5842TM-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW5842E-Z4E"
      },
      {
        "New Ref Code": "IPC-HFW5842E-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW5842E-Z4E"
      },
      {
        "New Ref Code": "IPC-HFW5842E-ZE"
      },
      {
        "New Ref Code": "IPC-HDW5842T-ZE"
      },
      {
        "New Ref Code": "IPC-HF5842F-ZE"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-Z4HE"
      },
      {
        "New Ref Code": "IPC-HDBW5842H-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW71242H-Z-X"
      },
      {
        "New Ref Code": "IPC-HDBW71242E1-Z-X"
      },
      {
        "New Ref Code": "IPC-HF71242F-Z-X"
      },
      {
        "New Ref Code": "IPC-HFW7442H-Z-S2"
      },
      {
        "New Ref Code": "IPC-HF7442F-Z-X"
      },
      {
        "New Ref Code": "IPC-HF7842F-Z-S2"
      },
      {
        "New Ref Code": "IPC-HFW7842H-Z-S2"
      },
      {
        "New Ref Code": "IPC-HFW7842H-Z-X"
      },
      {
        "New Ref Code": "IPC-HCBW8442P"
      },
      {
        "New Ref Code": "IPC-HDW8441X-3D"
      },
      {
        "New Ref Code": "IPC-HDEW8841R-Z"
      },
      {
        "New Ref Code": "IPC-HDBW5441F-AS-E2"
      },
      {
        "New Ref Code": "IPC-HDW3241EMP-AS"
      },
      {
        "New Ref Code": "IPC-HDW3241EMP-AS"
      },
      {
        "New Ref Code": "IPC-HDW3541EMP-AS"
      },
      {
        "New Ref Code": "IPC-HDW3541EMP-AS"
      },
      {
        "New Ref Code": "IPC-HFW3449T1-AS-PV"
      },
      {
        "New Ref Code": "IPC-HFW3549T1-AS-PV"
      },
      {
        "New Ref Code": "IPC-HFW3849T1-AS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3549H-AS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3849H-AS-PV"
      },
      {
        "New Ref Code": "IPC-HFW2841S-S"
      },
      {
        "New Ref Code": "IPC-HDW2841TM-S"
      },
      {
        "New Ref Code": "IPC-HFW2541S-S"
      },
      {
        "New Ref Code": "IPC-HDBW2841R-ZS"
      },
      {
        "New Ref Code": "IPC-HDW2549T-S-IL"
      },
      {
        "New Ref Code": "IPC-HDBW2541R-ZAS"
      },
      {
        "New Ref Code": "IPC-HFW2541T-ZS"
      },
      {
        "New Ref Code": "IPC-HFW2841T-AS"
      },
      {
        "New Ref Code": "IPC-HDBW2841E-S"
      },
      {
        "New Ref Code": "IPC-HFW2841T-ZS"
      },
      {
        "New Ref Code": "IPC-HFW2841T-ZAS"
      },
      {
        "New Ref Code": "IPC-HDBW2541E-S"
      },
      {
        "New Ref Code": "IPC-HFW2249T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HFW2249T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HFW2249T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HFW2449T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HFW2449T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HFW2449T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HFW2241S-S"
      },
      {
        "New Ref Code": "IPC-HDBW2241E-S"
      },
      {
        "New Ref Code": "IPC-HDW2241T-S"
      },
      {
        "New Ref Code": "IPC-HFW2241T-AS"
      },
      {
        "New Ref Code": "IPC-HDW2241TM-S"
      },
      {
        "New Ref Code": "IPC-HFW2249S-S-IL"
      },
      {
        "New Ref Code": "IPC-HDW2249T-S-IL"
      },
      {
        "New Ref Code": "IPC-HFW2241T-ZS"
      },
      {
        "New Ref Code": "IPC-HFW2241T-ZAS"
      },
      {
        "New Ref Code": "IPC-HDW2241T-ZS"
      },
      {
        "New Ref Code": "IPC-HDBW2241R-ZS"
      },
      {
        "New Ref Code": "IPC-HDBW2241R-ZAS"
      },
      {
        "New Ref Code": "IPC-HDW2249TM-S-IL"
      },
      {
        "New Ref Code": "IPC-HFW2441S-S"
      },
      {
        "New Ref Code": "IPC-HDBW2441E-S"
      },
      {
        "New Ref Code": "IPC-HDW2441T-S"
      },
      {
        "New Ref Code": "IPC-HFW2441T-AS"
      },
      {
        "New Ref Code": "IPC-HDW2441TM-S"
      },
      {
        "New Ref Code": "IPC-HFW2441T-ZS"
      },
      {
        "New Ref Code": "IPC-HFW2441T-ZAS"
      },
      {
        "New Ref Code": "IPC-HDW2441T-ZS"
      },
      {
        "New Ref Code": "IPC-HDBW2441R-ZS"
      },
      {
        "New Ref Code": "IPC-HDBW2441R-ZAS"
      },
      {
        "New Ref Code": "IPC-HDW2449TM-S-IL"
      },
      {
        "New Ref Code": "IPC-HFW2449S-S-IL"
      },
      {
        "New Ref Code": "IPC-HFW2449S-S-IL"
      },
      {
        "New Ref Code": "IPC-HDW2449T-S-IL"
      },
      {
        "New Ref Code": "IPC-HFW2541E-S"
      },
      {
        "New Ref Code": "IPC-HFW2541T-ZS"
      },
      {
        "New Ref Code": "IPC-HFW2541T-ZAS"
      },
      {
        "New Ref Code": "IPC-HDW2541T-ZS"
      },
      {
        "New Ref Code": "IPC-HFW2541T-AS"
      },
      {
        "New Ref Code": "IPC-HFW2541T-AS"
      },
      {
        "New Ref Code": "IPC-HFW2541T-AS"
      },
      {
        "New Ref Code": "IPC-HFW2549T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HFW2549T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HFW2849T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HFW2849T-AS-IL"
      },
      {
        "New Ref Code": "IPC-HDW3241TMP-AS"
      },
      {
        "New Ref Code": "IPC-HDW3241TMP-AS"
      },
      {
        "New Ref Code": "IPC-HDW3241TMP-AS"
      },
      {
        "New Ref Code": "IPC-HDW3241EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW3241EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW3241EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3241E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3241E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3241E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3241E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3241E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3241E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241F-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241F-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241F-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3241F-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW3241T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3241T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDW3441TMP-AS"
      },
      {
        "New Ref Code": "IPC-HDW3441TMP-AS"
      },
      {
        "New Ref Code": "IPC-HFW3441EP-AS"
      },
      {
        "New Ref Code": "IPC-HFW3441EP-AS"
      },
      {
        "New Ref Code": "IPC-HFW3441EP-SA"
      },
      {
        "New Ref Code": "IPC-HFW3441EP-SA"
      },
      {
        "New Ref Code": "IPC-HFW3441EP-SA"
      },
      {
        "New Ref Code": "IPC-HFW3449T1-ZAS-PV"
      },
      {
        "New Ref Code": "IPC-HDBW3449R1-ZAS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3441EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW3441EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW3441EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3441E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3441E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3441E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3441E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3441E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441F-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441F-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441F-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441F-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441R-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441R-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDW3441T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3441T-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3441T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3441R-AS-P"
      },
      {
        "New Ref Code": "IPC-HFW3449T1-AS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3449H-AS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3449H-AS-PV"
      },
      {
        "New Ref Code": "IPC-HDBW3541RP-ZAS"
      },
      {
        "New Ref Code": "IPC-HDBW3541RP-ZS"
      },
      {
        "New Ref Code": "IPC-HFW3549EP-AS-LED"
      },
      {
        "New Ref Code": "IPC-HFW3549T1-ZAS-PV"
      },
      {
        "New Ref Code": "IPC-HDBW3549R1-ZAS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3541EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW3541EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW3541EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3541E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3541E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3541E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3541E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3541E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3541E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3541F-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3541R-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3541R-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDW3541T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3541T-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3541T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3549T1-AS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3549H-AS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3841EMP-AS"
      },
      {
        "New Ref Code": "IPC-HFW3849T1-ZAS-PV"
      },
      {
        "New Ref Code": "IPC-HDBW3849R1-ZAS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3841EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW3841EM-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3841E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3841E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3841E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3841E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3841E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3841E-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3841E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW3841E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3841R-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW3841R-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDW3841T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3841T-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3841T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW3849T1-AS-PV"
      },
      {
        "New Ref Code": "IPC-HDW3849H-AS-PV"
      },
      {
        "New Ref Code": "IPC-HDW2431EMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2531EMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2531EMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2831EMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2831EMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2231FP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2231FP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2239SP-SA-LED-S2"
      },
      {
        "New Ref Code": "IPC-HDW2239TP-AS-LED-S2"
      },
      {
        "New Ref Code": "IPC-HDW2231TM-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2231T-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2231S-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW2231T-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2231T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2231M-AS-I2-B-S2"
      },
      {
        "New Ref Code": "IPC-HFW2231T-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2231T-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2231E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW2231T-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2231E-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW2231M-AS-I2-B-S2"
      },
      {
        "New Ref Code": "IPC-HFW2230S-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2230E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2231R-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2231T-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2231R-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2230E-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW2230T-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2230S-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW2230T-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2431FP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2431FP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2431TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2431TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2431TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2439SP-SA-LED-S2"
      },
      {
        "New Ref Code": "IPC-HDW2439TP-AS-LED-S2"
      },
      {
        "New Ref Code": "IPC-HDW2439TP-AS-LED-S2"
      },
      {
        "New Ref Code": "IPC-HDW2431TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2431EP-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW2431TP-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2431RP-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2431RP-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2431TP-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2431TP-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2431EP-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW2431SP-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW2431SP-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW2431TMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2431TMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2531TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2531TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2531TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2531TP-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2531TP-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2531SP-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW2531SP-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW2531TP-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2531TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2531TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2531RP-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2531RP-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2531EP-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2531EP-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW2531TMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2531TMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2831TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2831TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2831RP-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2831TP-ZAS-S2"
      },
      {
        "New Ref Code": "IPC-HFW2831TP-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2831TP-ZS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2831TMP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2831TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDW2831TP-AS-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2831EP-S-S2"
      },
      {
        "New Ref Code": "IPC-HDBW2831EP-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW2831SP-S-S2"
      },
      {
        "New Ref Code": "IPC-HFW2831SP-S-S2"
      },
      {
        "New Ref Code": "IPC-HDW1230DT1-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230DT1-S5"
      },
      {
        "New Ref Code": "IPC-HFW1431M-A-I1-B-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431M-A-I1-B-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431M-A-I2-B-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431M-A-I2-B-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431M-A-I2-B-S4"
      },
      {
        "New Ref Code": "IPC-HFW1439S-A-LED-S4"
      },
      {
        "New Ref Code": "IPC-HFW1239S-A-LED-S5"
      },
      {
        "New Ref Code": "IPC-HDW1439T-A-LED-S4"
      },
      {
        "New Ref Code": "IPC-HDW1239T-A-LED-S5"
      },
      {
        "New Ref Code": "IPC-HFW1430S-A-S5"
      },
      {
        "New Ref Code": "IPC-HFW1430S-A-S5"
      },
      {
        "New Ref Code": "IPC-HDW1430T-A-S5"
      },
      {
        "New Ref Code": "IPC-HDW1430T-A-S5"
      },
      {
        "New Ref Code": "IPC-HFW1430S-S5"
      },
      {
        "New Ref Code": "IPC-HFW1430S-S5"
      },
      {
        "New Ref Code": "IPC-HDW1430T-S5"
      },
      {
        "New Ref Code": "IPC-HDW1430T-S5"
      },
      {
        "New Ref Code": "IPC-HDBW1430E-S5"
      },
      {
        "New Ref Code": "IPC-HDBW1430E-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230S-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230S-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230S1-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230S1-S5"
      },
      {
        "New Ref Code": "IPC-HDPW1230R1-S5"
      },
      {
        "New Ref Code": "IPC-HDPW1230R1-S5"
      },
      {
        "New Ref Code": "IPC-HDBW1230E-S5"
      },
      {
        "New Ref Code": "IPC-HDBW1230E-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230S-S5"
      },
      {
        "New Ref Code": "IPC-HDW1239T1-LED-S5"
      },
      {
        "New Ref Code": "IPC-HDW1239T1-LED-S5"
      },
      {
        "New Ref Code": "IPC-HFW1239S1-LED-S5"
      },
      {
        "New Ref Code": "IPC-HFW1239S1-LED-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230M-A-I1-B-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230M-A-I2-B-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230M-A-I2-B-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230M-A-I2-B-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230T1-ZS-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230T-ZS-S5"
      },
      {
        "New Ref Code": "IPC-HDPW1230R1-ZS-S5"
      },
      {
        "New Ref Code": "IPC-HDBW1230R-ZS-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230T1-ZS-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230DS1-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230T-ZS-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230DS1-S5"
      },
      {
        "New Ref Code": "IPC-HFW1239S1-LED-S5"
      },
      {
        "New Ref Code": "IPC-HDW1239T1-LED-S5"
      },
      {
        "New Ref Code": "IPC-HFW1239S1-LED-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230T1-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230S1-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230S-S5"
      },
      {
        "New Ref Code": "IPC-HFW1239S1-A-LED-S5"
      },
      {
        "New Ref Code": "IPC-HFW1239S1-A-LED-S5"
      },
      {
        "New Ref Code": "IPC-HDW1239T1-A-LED-S5"
      },
      {
        "New Ref Code": "IPC-HDW1239T1-A-LED-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230S1-A-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230S1-A-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230T1-A-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230T1-A-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230S-A-S5"
      },
      {
        "New Ref Code": "IPC-HFW1230S-A-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230T-A-S5"
      },
      {
        "New Ref Code": "IPC-HDW1230T-A-S5"
      },
      {
        "New Ref Code": "IPC-HFW1239S-A-LED-S5"
      },
      {
        "New Ref Code": "IPC-HDW1239T-A-LED-S5"
      },
      {
        "New Ref Code": "IPC-HFW1431TP-ZS-S4"
      },
      {
        "New Ref Code": "IPC-HDW1431TP-ZS-S4"
      },
      {
        "New Ref Code": "IPC-HDBW1431RP-ZS-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431SP-S4"
      },
      {
        "New Ref Code": "IPC-HDPW1431R1P-S4"
      },
      {
        "New Ref Code": "IPC-HDW1431SP-S4"
      },
      {
        "New Ref Code": "IPC-HDW1431SP-S4"
      },
      {
        "New Ref Code": "IPC-HDBW1431EP-S4"
      },
      {
        "New Ref Code": "IPC-HDBW1431EP-S4"
      },
      {
        "New Ref Code": "IPC-HDW1431T1P-S4"
      },
      {
        "New Ref Code": "IPC-HDW1431T1P-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431S1P-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431S1P-S4"
      },
      {
        "New Ref Code": "IPC-HDPW1431R1P-S4"
      },
      {
        "New Ref Code": "IPC-HDPW1431R1P-ZS-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431T1P-ZS-S4"
      },
      {
        "New Ref Code": "IPC-HDW1431T1P-ZS-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431S1-A-S4"
      },
      {
        "New Ref Code": "IPC-HFW1431S1-A-S4"
      },
      {
        "New Ref Code": "IPC-HDW1431T1-A-S4"
      },
      {
        "New Ref Code": "IPC-HDW1431T1-A-S4"
      },
      {
        "New Ref Code": "IPC-HFW1430S1-A-S5"
      },
      {
        "New Ref Code": "IPC-HFW1430S1-A-S5"
      },
      {
        "New Ref Code": "IPC-HDW1439T1-A-LED-S4"
      },
      {
        "New Ref Code": "IPC-HFW1439S1-LED-S4"
      },
      {
        "New Ref Code": "IPC-HDW1430T1-A-S5"
      },
      {
        "New Ref Code": "IPC-HFW1439S1-LED-S4"
      },
      {
        "New Ref Code": "IPC-HDW1430T1-A-S5"
      },
      {
        "New Ref Code": "IPC-HDW1439T1-A-LED-S4"
      },
      {
        "New Ref Code": "IPC-HDW1439T1-LED-S4"
      },
      {
        "New Ref Code": "IPC-HFW1439S1-A-LED-S4"
      },
      {
        "New Ref Code": "IPC-HDPW1430R1-S5"
      },
      {
        "New Ref Code": "IPC-HDW1439T1-LED-S4"
      },
      {
        "New Ref Code": "IPC-HDPW1430R1-S5"
      },
      {
        "New Ref Code": "IPC-HFW1439S1-A-LED-S4"
      },
      {
        "New Ref Code": "IPC-HFW1430S1-S5"
      },
      {
        "New Ref Code": "IPC-HFW1430S1-S5"
      },
      {
        "New Ref Code": "IPC-HDW1430T1-S5"
      },
      {
        "New Ref Code": "IPC-HFW1439S-A-LED-S4"
      },
      {
        "New Ref Code": "IPC-HDW1439T-A-LED-S4"
      },
      {
        "New Ref Code": "IPC-HFW1530S-S6"
      },
      {
        "New Ref Code": "IPC-HFW1530S-S6"
      },
      {
        "New Ref Code": "IPC-HDW1530T-S6"
      },
      {
        "New Ref Code": "IPC-HDBW1530E-S6"
      },
      {
        "New Ref Code": "IPC-HFW1830S-S6"
      },
      {
        "New Ref Code": "IPC-HFW1830S-S6"
      },
      {
        "New Ref Code": "IPC-HDW1830T-S6"
      },
      {
        "New Ref Code": "IPC-HDW1830T-S6"
      },
      {
        "New Ref Code": "IPC-HDBW1830E-S6"
      },
      {
        "New Ref Code": "IPC-HDBW1830E-S6"
      },
      {
        "New Ref Code": "IPC-HFW5831EP-ZHE"
      },
      {
        "New Ref Code": "IPC-HFW4831EP-SE"
      },
      {
        "New Ref Code": "IPC-HFW4831TP-ASE"
      },
      {
        "New Ref Code": "IPC-HDW4831EMP-ASE"
      },
      {
        "New Ref Code": "IPC-HDBW4831EP-ASE"
      },
      {
        "New Ref Code": "IPC-HFW5831EP-ZE"
      },
      {
        "New Ref Code": "IPC-HDBW5831EP-ZHE"
      },
      {
        "New Ref Code": "IPC-HDW5831RP-ZE"
      },
      {
        "New Ref Code": "IPC-HDBW5831EP-ZE"
      },
      {
        "New Ref Code": "IPC-HFW5831EP-Z5E"
      },
      {
        "New Ref Code": "IPC-HFW2431DG-4G-SP-EAU-B"
      },
      {
        "New Ref Code": "IPC-HFW3441DG-AS-4G-EAU-B"
      },
      {
        "New Ref Code": "IPC-HFW1230DT-STW"
      },
      {
        "New Ref Code": "IPC-HDW1230DT-STW"
      },
      {
        "New Ref Code": "IPC-HFW1230DS-SAW"
      },
      {
        "New Ref Code": "IPC-HDBW1230DE-SW"
      },
      {
        "New Ref Code": "IPC-HFW1230DS1-SAW"
      },
      {
        "New Ref Code": "IPC-HDW1230DT-SAW"
      },
      {
        "New Ref Code": "IPC-HFW1430DT-STW"
      },
      {
        "New Ref Code": "IPC-HDW1430DT-STW"
      },
      {
        "New Ref Code": "IPC-HFW1430DS-SAW"
      },
      {
        "New Ref Code": "IPC-HDBW1430DE-SW"
      },
      {
        "New Ref Code": "IPC-HFW1430DS1-SAW"
      },
      {
        "New Ref Code": "IPC-HDW1430DT-SAW"
      },
      {
        "New Ref Code": "IPC-HDBW3541FP-AS-M"
      }
    ],
    "IPC-P": [
      {
        "New Ref Code": "IPC-PFW81642-A180"
      },
      {
        "New Ref Code": "IPC-PFW5849-A180-E2-ASTE"
      },
      {
        "New Ref Code": "IPC-PDW5849-A180-E2-ASTE"
      },
      {
        "New Ref Code": "IPC-PDW3849-A180-AS-PV"
      },
      {
        "New Ref Code": "IPC-PDBW5831P-B360"
      }
    ],
    "IPC-W": [
      {
        "New Ref Code": "IPC-WL46A"
      }
    ]
  },
  "ISC": {
    "ISC-D": [
      {
        "New Ref Code": "ISC-D118C"
      },
      {
        "New Ref Code": "ISC-D118"
      },
      {
        "New Ref Code": "ISC-D118-T"
      },
      {
        "New Ref Code": "ISC-D1XX-U"
      },
      {
        "New Ref Code": "ISC-D118C"
      },
      {
        "New Ref Code": "ISC-D733-TS2"
      },
      {
        "New Ref Code": "ISC-D733-S2"
      },
      {
        "New Ref Code": "ISC-D109L"
      }
    ],
    "ISC-H": [
      {
        "New Ref Code": "ISC-H001"
      }
    ],
    "ISC-M": [
      {
        "New Ref Code": "ISC-M6550"
      }
    ]
  },
  "IVS": {
    "IVS-F": [
      {
        "New Ref Code": "IVS-F7500-T-S2-GU2"
      },
      {
        "New Ref Code": "IVS-F7500-2T-S2-GU2"
      }
    ],
    "IVS-T": [
      {
        "New Ref Code": "IVS-T8100-S-GU2"
      }
    ]
  },
  "KVM": {
    "KVM-S": [
      {
        "New Ref Code": "KVM-SOFT"
      }
    ]
  },
  "LM19": {
    "LM19-": [
      {
        "New Ref Code": "LM19-L200"
      }
    ]
  },
  "LM22": {
    "LM22-": [
      {
        "New Ref Code": "LM22-B200S"
      },
      {
        "New Ref Code": "LM22-H200"
      },
      {
        "New Ref Code": "LM22-B200"
      },
      {
        "New Ref Code": "LM22-F200"
      },
      {
        "New Ref Code": "LM22-A200"
      },
      {
        "New Ref Code": "LM22-L200"
      }
    ]
  },
  "LM24": {
    "LM24-": [
      {
        "New Ref Code": "LM24-B200S"
      },
      {
        "New Ref Code": "LM24-B201S"
      },
      {
        "New Ref Code": "LM24-F200"
      },
      {
        "New Ref Code": "LM24-L200"
      },
      {
        "New Ref Code": "LM24-P301A"
      },
      {
        "New Ref Code": "LM24-E231"
      },
      {
        "New Ref Code": "LM24-E230C"
      }
    ]
  },
  "LM27": {
    "LM27-": [
      {
        "New Ref Code": "LM27-A200"
      },
      {
        "New Ref Code": "LM27-B200S"
      },
      {
        "New Ref Code": "LM27-B200S"
      },
      {
        "New Ref Code": "LM27-B201S"
      },
      {
        "New Ref Code": "LM27-C200"
      },
      {
        "New Ref Code": "LM27-B200S"
      },
      {
        "New Ref Code": "LM27-E231"
      },
      {
        "New Ref Code": "LM27-E230C"
      },
      {
        "New Ref Code": "LM27-B200"
      }
    ]
  },
  "LM28": {
    "LM28-": [
      {
        "New Ref Code": "LM28-F400"
      }
    ]
  },
  "LM32": {
    "LM32-": [
      {
        "New Ref Code": "LM32-S200"
      },
      {
        "New Ref Code": "LM32-P301A"
      },
      {
        "New Ref Code": "LM32-E230C"
      },
      {
        "New Ref Code": "LM32-F200"
      }
    ]
  },
  "LM34": {
    "LM34-": [
      {
        "New Ref Code": "LM34-E330C"
      },
      {
        "New Ref Code": "LM34-E330C"
      }
    ]
  },
  "LM43": {
    "LM43-": [
      {
        "New Ref Code": "LM43-S200"
      },
      {
        "New Ref Code": "LM43-F200"
      },
      {
        "New Ref Code": "LM43-S400"
      },
      {
        "New Ref Code": "LM43-S400"
      }
    ]
  },
  "LM49": {
    "LM49-": [
      {
        "New Ref Code": "LM49-S400"
      },
      {
        "New Ref Code": "LM49-S400"
      }
    ]
  },
  "LM50": {
    "LM50-": [
      {
        "New Ref Code": "LM50-F400"
      }
    ]
  },
  "LM55": {
    "LM55-": [
      {
        "New Ref Code": "LM55-F400"
      },
      {
        "New Ref Code": "LM55-F400"
      },
      {
        "New Ref Code": "LM55-S400"
      },
      {
        "New Ref Code": "LM55-S400"
      }
    ]
  },
  "LM65": {
    "LM65-": [
      {
        "New Ref Code": "LM65-S400"
      },
      {
        "New Ref Code": "LM65-F400"
      }
    ]
  },
  "LS": {
    "LS-HW": [
      {
        "New Ref Code": "LS-HW"
      }
    ]
  },
  "M70": {
    "M70-4": [
      {
        "New Ref Code": "M70-4U-E"
      }
    ],
    "M70-D": [
      {
        "New Ref Code": "M70-D-0205HO"
      }
    ]
  },
  "MC": {
    "MC-PI": [
      {
        "New Ref Code": "MC-PI5681IL"
      }
    ]
  },
  "NM": {
    "NM-N1": [
      {
        "New Ref Code": "NM-N100-64GB"
      },
      {
        "New Ref Code": "NM-N100-128GB"
      },
      {
        "New Ref Code": "NM-N100-256GB"
      }
    ]
  },
  "PKC": {
    "PKC-M": [
      {
        "New Ref Code": "PKC-MS0A"
      },
      {
        "New Ref Code": "PKC-MS1A"
      }
    ]
  },
  "PKP": {
    "PKP-W": [
      {
        "New Ref Code": "PKP-WP0B"
      }
    ]
  },
  "PSSD": {
    "PSSD-": [
      {
        "New Ref Code": "PSSD-T70-1TB"
      },
      {
        "New Ref Code": "PSSD-T70-500G"
      },
      {
        "New Ref Code": "PSSD-T60-500G"
      },
      {
        "New Ref Code": "PSSD-T70-500G"
      },
      {
        "New Ref Code": "PSSD-T70-1TB"
      }
    ]
  },
  "SD": {
    "SD-H1": [
      {
        "New Ref Code": "SD-H100-32GB"
      },
      {
        "New Ref Code": "SD-H100-64GB"
      },
      {
        "New Ref Code": "SD-H100-128GB"
      },
      {
        "New Ref Code": "SD-H100-256GB"
      }
    ]
  },
  "SSD": {
    "SSD-C": [
      {
        "New Ref Code": "SSD-C800AS128G"
      },
      {
        "New Ref Code": "SSD-C800AS256G"
      },
      {
        "New Ref Code": "SSD-C800AS2000G"
      },
      {
        "New Ref Code": "SSD-C800AS500G"
      },
      {
        "New Ref Code": "SSD-C970N256G"
      },
      {
        "New Ref Code": "SSD-C970N512G"
      },
      {
        "New Ref Code": "SSD-C970N1TB"
      },
      {
        "New Ref Code": "SSD-C800AS120G"
      },
      {
        "New Ref Code": "SSD-C800AS128G"
      },
      {
        "New Ref Code": "SSD-C800AS240G"
      },
      {
        "New Ref Code": "SSD-C800AS256G"
      },
      {
        "New Ref Code": "SSD-C900VN256G"
      },
      {
        "New Ref Code": "SSD-C900VN512G"
      },
      {
        "New Ref Code": "SSD-C900VN1TB"
      },
      {
        "New Ref Code": "SSD-C800AS480G"
      },
      {
        "New Ref Code": "SSD-C800AS512G"
      },
      {
        "New Ref Code": "SSD-C800AS960G"
      },
      {
        "New Ref Code": "SSD-C800N256G"
      },
      {
        "New Ref Code": "SSD-C800N512G"
      },
      {
        "New Ref Code": "SSD-C800N1TB"
      },
      {
        "New Ref Code": "SSD-C800AS1TB"
      },
      {
        "New Ref Code": "SSD-C800AS2TB"
      },
      {
        "New Ref Code": "SSD-C970PN1TB"
      },
      {
        "New Ref Code": "SSD-C800AS1TB"
      },
      {
        "New Ref Code": "SSD-C800AS2TB"
      },
      {
        "New Ref Code": "SSD-C900VN2TB-B"
      },
      {
        "New Ref Code": "SSD-C900N256G"
      },
      {
        "New Ref Code": "SSD-C900N512G"
      },
      {
        "New Ref Code": "SSD-C900N1TB"
      },
      {
        "New Ref Code": "SSD-C970VN1TB"
      },
      {
        "New Ref Code": "SSD-C800AS960G"
      },
      {
        "New Ref Code": "SSD-C800AS1000G"
      },
      {
        "New Ref Code": "SSD-C800AS128G"
      },
      {
        "New Ref Code": "SSD-C800AS256G"
      },
      {
        "New Ref Code": "SSD-C800AS128G"
      },
      {
        "New Ref Code": "SSD-C800AS256G"
      },
      {
        "New Ref Code": "SSD-C800AS512G"
      },
      {
        "New Ref Code": "SSD-C800AS512G"
      },
      {
        "New Ref Code": "SSD-C800N256G"
      },
      {
        "New Ref Code": "SSD-C800N512G"
      },
      {
        "New Ref Code": "SSD-C800N1TB"
      },
      {
        "New Ref Code": "SSD-C900VN256G"
      },
      {
        "New Ref Code": "SSD-C900VN512G"
      },
      {
        "New Ref Code": "SSD-C900VN1TB"
      },
      {
        "New Ref Code": "SSD-C970PN1TB"
      }
    ],
    "SSD-E": [
      {
        "New Ref Code": "SSD-E900N256G"
      },
      {
        "New Ref Code": "SSD-E900N256G"
      },
      {
        "New Ref Code": "SSD-E900N512G"
      },
      {
        "New Ref Code": "SSD-E900N1TB"
      },
      {
        "New Ref Code": "SSD-E800S128G"
      },
      {
        "New Ref Code": "SSD-E800S256G"
      },
      {
        "New Ref Code": "SSD-E800S512G"
      },
      {
        "New Ref Code": "SSD-E900N128G"
      },
      {
        "New Ref Code": "SSD-E800S128G"
      },
      {
        "New Ref Code": "SSD-E800S256G"
      },
      {
        "New Ref Code": "SSD-E900N256G"
      },
      {
        "New Ref Code": "SSD-E900N512G"
      }
    ],
    "SSD-S": [
      {
        "New Ref Code": "SSD-S820GS512G"
      },
      {
        "New Ref Code": "SSD-S820GS2TB"
      },
      {
        "New Ref Code": "SSD-S820N512G-G1YTTANN8"
      },
      {
        "New Ref Code": "SSD-S820N1TB-G1YTTANN8"
      },
      {
        "New Ref Code": "SSD-S810GS240G"
      },
      {
        "New Ref Code": "SSD-S810GS480G"
      },
      {
        "New Ref Code": "SSD-S810GS960G"
      },
      {
        "New Ref Code": "SSD-S820GS1TB"
      }
    ]
  },
  "T2A": {
    "T2A-L": [
      {
        "New Ref Code": "T2A-LED"
      }
    ],
    "T2A-P": [
      {
        "New Ref Code": "T2A-PV"
      }
    ]
  },
  "T4A": {
    "T4A-L": [
      {
        "New Ref Code": "T4A-LED"
      }
    ],
    "T4A-P": [
      {
        "New Ref Code": "T4A-PV"
      }
    ]
  },
  "TF": {
    "TF-C1": [
      {
        "New Ref Code": "TF-C100/32GB"
      },
      {
        "New Ref Code": "TF-C100/64GB"
      },
      {
        "New Ref Code": "TF-C100/128GB"
      },
      {
        "New Ref Code": "TF-C100/256GB"
      },
      {
        "New Ref Code": "TF-C100/512GB"
      }
    ],
    "TF-K1": [
      {
        "New Ref Code": "TF-K100-8GB"
      },
      {
        "New Ref Code": "TF-K100-16GB"
      },
      {
        "New Ref Code": "TF-K100-32GB"
      },
      {
        "New Ref Code": "TF-K100-64GB"
      }
    ],
    "TF-L1": [
      {
        "New Ref Code": "TF-L100-128GB"
      },
      {
        "New Ref Code": "TF-L100-256GB"
      }
    ],
    "TF-P1": [
      {
        "New Ref Code": "TF-P100/32GB"
      },
      {
        "New Ref Code": "TF-P100/64GB"
      },
      {
        "New Ref Code": "TF-P100/128GB"
      },
      {
        "New Ref Code": "TF-P100/256GB"
      },
      {
        "New Ref Code": "TF-P100/512GB"
      }
    ],
    "TF-W1": [
      {
        "New Ref Code": "TF-W100-32GB"
      },
      {
        "New Ref Code": "TF-W100-64GB"
      },
      {
        "New Ref Code": "TF-W100-128GB"
      },
      {
        "New Ref Code": "TF-W100-256GB"
      }
    ]
  },
  "TSFP": {
    "TSFP-": [
      {
        "New Ref Code": "TSFP-1310-20-SMF"
      }
    ]
  },
  "USB": {
    "USB-P": [
      {
        "New Ref Code": "USB-P629-32-32GB"
      },
      {
        "New Ref Code": "USB-P629-32-32GB"
      },
      {
        "New Ref Code": "USB-P629-32-32GB"
      },
      {
        "New Ref Code": "USB-P629-32-64GB"
      },
      {
        "New Ref Code": "USB-P629-32-128GB"
      },
      {
        "New Ref Code": "USB-P629-32-256GB"
      },
      {
        "New Ref Code": "USB-P639-32-32GB"
      },
      {
        "New Ref Code": "USB-P639-32-64GB"
      },
      {
        "New Ref Code": "USB-P639-32-128GB"
      }
    ],
    "USB-S": [
      {
        "New Ref Code": "USB-S806-32-128GB"
      },
      {
        "New Ref Code": "USB-S806-32-256GB"
      },
      {
        "New Ref Code": "USB-S806-32-512GB"
      },
      {
        "New Ref Code": "USB-S809-32-128GB"
      },
      {
        "New Ref Code": "USB-S809-32-256GB"
      }
    ],
    "USB-U": [
      {
        "New Ref Code": "USB-U166-31-32G"
      },
      {
        "New Ref Code": "USB-U166-31-64G"
      },
      {
        "New Ref Code": "USB-U176-20-8G"
      },
      {
        "New Ref Code": "USB-U176-20-16G"
      },
      {
        "New Ref Code": "USB-U176-20-32G"
      },
      {
        "New Ref Code": "USB-U176-20-64G"
      },
      {
        "New Ref Code": "USB-U176-31-32G"
      },
      {
        "New Ref Code": "USB-U176-31-64G"
      },
      {
        "New Ref Code": "USB-U176-31-128G"
      },
      {
        "New Ref Code": "USB-U176-31-256G"
      },
      {
        "New Ref Code": "USB-U126-20-4GB"
      },
      {
        "New Ref Code": "USB-U126-20-8GB"
      },
      {
        "New Ref Code": "USB-U126-20-16GB"
      },
      {
        "New Ref Code": "USB-U126-20-32GB"
      },
      {
        "New Ref Code": "USB-U126-30-16GB"
      },
      {
        "New Ref Code": "USB-U126-30-32GB"
      },
      {
        "New Ref Code": "USB-U126-30-64GB"
      },
      {
        "New Ref Code": "USB-U106-20-4GB"
      },
      {
        "New Ref Code": "USB-U106-20-8GB"
      },
      {
        "New Ref Code": "USB-U106-20-16GB"
      },
      {
        "New Ref Code": "USB-U106-20-32GB"
      },
      {
        "New Ref Code": "USB-U106-20-64GB"
      },
      {
        "New Ref Code": "USB-U106-30-16GB"
      },
      {
        "New Ref Code": "USB-U106-30-32GB"
      },
      {
        "New Ref Code": "USB-U106-30-64GB"
      },
      {
        "New Ref Code": "USB-U106-30-128GB"
      },
      {
        "New Ref Code": "USB-U116-20-8GB"
      },
      {
        "New Ref Code": "USB-U116-20-16GB"
      },
      {
        "New Ref Code": "USB-U116-20-32GB"
      },
      {
        "New Ref Code": "USB-U116-20-64GB"
      },
      {
        "New Ref Code": "USB-U156-20-8GB"
      },
      {
        "New Ref Code": "USB-U156-20-16GB"
      },
      {
        "New Ref Code": "USB-U156-20-32GB"
      },
      {
        "New Ref Code": "USB-U156-32-32GB"
      },
      {
        "New Ref Code": "USB-U156-32-64GB"
      },
      {
        "New Ref Code": "USB-U156-32-128GB"
      }
    ]
  },
  "VCS": {
    "VCS-M": [
      {
        "New Ref Code": "VCS-MCA400"
      }
    ]
  },
  "eHDD": {
    "eHDD-": [
      {
        "New Ref Code": "eHDD-E10-1T"
      },
      {
        "New Ref Code": "eHDD-E10-1T"
      },
      {
        "New Ref Code": "eHDD-E10-2T"
      },
      {
        "New Ref Code": "eHDD-E10-2T"
      }
    ]
  }
}

# %%
group_data_without_hyphen = {
  "8019": {
    "8019": [
      {
        "New Ref Code": "8019"
      }
    ]
  },
  "AC12": {
    "AC12": [
      {
        "New Ref Code": "AC12"
      }
    ]
  },
  "AR306": {
    "AR306": [
      {
        "New Ref Code": "AR306-E"
      }
    ]
  },
  "AR506": {
    "AR506": [
      {
        "New Ref Code": "AR506-E"
      }
    ]
  },
  "ARA12": {
    "ARA12": [
      {
        "New Ref Code": "ARA12-W2(868)"
      }
    ]
  },
  "ARA13": {
    "ARA13": [
      {
        "New Ref Code": "ARA13-W2(868)"
      },
      {
        "New Ref Code": "ARA13-W2(868)"
      },
      {
        "New Ref Code": "ARA13-W2(868)"
      }
    ]
  },
  "ARA24": {
    "ARA24": [
      {
        "New Ref Code": "ARA24-W2(868)"
      }
    ]
  },
  "ARA43": {
    "ARA43": [
      {
        "New Ref Code": "ARA43-W2(868)"
      }
    ]
  },
  "ARC20": {
    "ARC20": [
      {
        "New Ref Code": "ARC2016C-V3"
      },
      {
        "New Ref Code": "ARC2008C-V3"
      }
    ]
  },
  "ARC30": {
    "ARC30": [
      {
        "New Ref Code": "ARC3000H-FW2(868)"
      },
      {
        "New Ref Code": "ARC3000H-W2(868)"
      },
      {
        "New Ref Code": "ARC3008C"
      }
    ]
  },
  "ARC90": {
    "ARC90": [
      {
        "New Ref Code": "ARC9016C-V3"
      }
    ]
  },
  "ARD12": {
    "ARD12": [
      {
        "New Ref Code": "ARD1233-W2(868)"
      }
    ]
  },
  "ARD17": {
    "ARD17": [
      {
        "New Ref Code": "ARD1731-W2(868)"
      }
    ]
  },
  "ARD22": {
    "ARD22": [
      {
        "New Ref Code": "ARD2231-W2(868)"
      }
    ]
  },
  "ARD32": {
    "ARD32": [
      {
        "New Ref Code": "ARD324-W2(868S)"
      },
      {
        "New Ref Code": "ARD323-W2(868)"
      },
      {
        "New Ref Code": "ARD323-W2(868S)"
      }
    ]
  },
  "ARD82": {
    "ARD82": [
      {
        "New Ref Code": "ARD821-W2(868)"
      },
      {
        "New Ref Code": "ARD822-W2(868)"
      },
      {
        "New Ref Code": "ARD821-W2(868)"
      },
      {
        "New Ref Code": "ARD821-W2(868)"
      }
    ]
  },
  "ARD91": {
    "ARD91": [
      {
        "New Ref Code": "ARD912-W2(868)"
      },
      {
        "New Ref Code": "ARD912-W2(868D)"
      }
    ]
  },
  "ARK30": {
    "ARK30": [
      {
        "New Ref Code": "ARK30T-W2(868)"
      },
      {
        "New Ref Code": "ARK30C"
      }
    ]
  },
  "ARK50": {
    "ARK50": [
      {
        "New Ref Code": "ARK50C-R"
      }
    ]
  },
  "ARM31": {
    "ARM31": [
      {
        "New Ref Code": "ARM310-W2(868)"
      }
    ]
  },
  "ARM32": {
    "ARM32": [
      {
        "New Ref Code": "ARM320-W2(868)"
      }
    ]
  },
  "ARM70": {
    "ARM70": [
      {
        "New Ref Code": "ARM7012-W2(868)"
      },
      {
        "New Ref Code": "ARM7011-W2(868)"
      },
      {
        "New Ref Code": "ARM708-RS"
      }
    ]
  },
  "ARM80": {
    "ARM80": [
      {
        "New Ref Code": "ARM801"
      },
      {
        "New Ref Code": "ARM802"
      },
      {
        "New Ref Code": "ARM808-RS"
      },
      {
        "New Ref Code": "ARM808"
      },
      {
        "New Ref Code": "ARM808"
      }
    ]
  },
  "ARM91": {
    "ARM91": [
      {
        "New Ref Code": "ARM911"
      }
    ]
  },
  "AS430": {
    "AS430": [
      {
        "New Ref Code": "AS4300-16GT4GF"
      },
      {
        "New Ref Code": "AS4300-24GT4GF"
      },
      {
        "New Ref Code": "AS4300-48GT4GF"
      }
    ]
  },
  "AS550": {
    "AS550": [
      {
        "New Ref Code": "AS5500-24MGT4XF-600"
      },
      {
        "New Ref Code": "AS5500-24GT4XF"
      },
      {
        "New Ref Code": "AS5500-24GT4XF-370"
      }
    ]
  },
  "AS560": {
    "AS560": [
      {
        "New Ref Code": "AS5600-24GT4XF"
      },
      {
        "New Ref Code": "AS5600-24GF4XF"
      },
      {
        "New Ref Code": "AS5600-48GF4XF"
      }
    ]
  },
  "AS660": {
    "AS660": [
      {
        "New Ref Code": "AS6600-24XF2QF"
      }
    ]
  },
  "ASA12": {
    "ASA12": [
      {
        "New Ref Code": "ASA1222GL"
      },
      {
        "New Ref Code": "ASA1222GL-D"
      },
      {
        "New Ref Code": "ASA1222E"
      },
      {
        "New Ref Code": "ASA1222G"
      },
      {
        "New Ref Code": "ASA1222G-D"
      }
    ]
  },
  "ASA32": {
    "ASA32": [
      {
        "New Ref Code": "ASA3223A-W"
      },
      {
        "New Ref Code": "ASA3213GL-MW"
      }
    ]
  },
  "ASC22": {
    "ASC22": [
      {
        "New Ref Code": "ASC2202B-D"
      },
      {
        "New Ref Code": "ASC2204B-S"
      },
      {
        "New Ref Code": "ASC2202C-S"
      },
      {
        "New Ref Code": "ASC2202C-D"
      },
      {
        "New Ref Code": "ASC2204C-S"
      },
      {
        "New Ref Code": "ASC2204C-D"
      },
      {
        "New Ref Code": "ASC2208C-S"
      }
    ]
  },
  "ASC32": {
    "ASC32": [
      {
        "New Ref Code": "ASC3202B"
      }
    ]
  },
  "ASF28": {
    "ASF28": [
      {
        "New Ref Code": "ASF280A"
      },
      {
        "New Ref Code": "ASF280B"
      }
    ]
  },
  "ASF80": {
    "ASF80": [
      {
        "New Ref Code": "ASF802"
      }
    ]
  },
  "ASGB1": {
    "ASGB1": [
      {
        "New Ref Code": "ASGB110K-L"
      },
      {
        "New Ref Code": "ASGB110K-R"
      },
      {
        "New Ref Code": "ASGB120K-D"
      }
    ]
  },
  "ASGB2": {
    "ASGB2": [
      {
        "New Ref Code": "ASGB211Z-L"
      },
      {
        "New Ref Code": "ASGB211Z-R"
      }
    ]
  },
  "ASGB6": {
    "ASGB6": [
      {
        "New Ref Code": "ASGB611K-L"
      }
    ]
  },
  "ASGG5": {
    "ASGG5": [
      {
        "New Ref Code": "ASGG520T"
      },
      {
        "New Ref Code": "ASGG500T"
      }
    ]
  },
  "ASI12": {
    "ASI12": [
      {
        "New Ref Code": "ASI1202M"
      },
      {
        "New Ref Code": "ASI1202M-D"
      },
      {
        "New Ref Code": "ASI1201E"
      },
      {
        "New Ref Code": "ASI1201E-D"
      },
      {
        "New Ref Code": "ASI1201A"
      }
    ]
  },
  "ASI22": {
    "ASI22": [
      {
        "New Ref Code": "ASI2212J"
      },
      {
        "New Ref Code": "ASI2212J-D"
      },
      {
        "New Ref Code": "ASI2212J-PW"
      },
      {
        "New Ref Code": "ASI2212J-DPW"
      },
      {
        "New Ref Code": "ASI2201H-DW"
      }
    ]
  },
  "ASI32": {
    "ASI32": [
      {
        "New Ref Code": "ASI3223A"
      },
      {
        "New Ref Code": "ASI3213A-W"
      },
      {
        "New Ref Code": "ASI3214A-W"
      },
      {
        "New Ref Code": "ASI3213G-MW"
      }
    ]
  },
  "ASI62": {
    "ASI62": [
      {
        "New Ref Code": "ASI6213S"
      },
      {
        "New Ref Code": "ASI6214S"
      },
      {
        "New Ref Code": "ASI6213S-D"
      },
      {
        "New Ref Code": "ASI6214S-D"
      },
      {
        "New Ref Code": "ASI6213S-PW"
      },
      {
        "New Ref Code": "ASI6214S-PW"
      },
      {
        "New Ref Code": "ASI6213J-MW"
      },
      {
        "New Ref Code": "ASI6214J-MFW"
      },
      {
        "New Ref Code": "ASI6213J-FT"
      },
      {
        "New Ref Code": "ASI6213J-FT1"
      }
    ]
  },
  "ASI72": {
    "ASI72": [
      {
        "New Ref Code": "ASI7213X"
      },
      {
        "New Ref Code": "ASI7214X"
      },
      {
        "New Ref Code": "ASI7223X-A"
      },
      {
        "New Ref Code": "ASI7213Y-V3"
      },
      {
        "New Ref Code": "ASI7214Y-V3"
      },
      {
        "New Ref Code": "ASI7223Y-A-V3"
      },
      {
        "New Ref Code": "ASI7213Y-V3-T1P"
      },
      {
        "New Ref Code": "ASI7223Y-A-V3-T1P"
      }
    ]
  },
  "ASI82": {
    "ASI82": [
      {
        "New Ref Code": "ASI8214Y-V3"
      },
      {
        "New Ref Code": "ASI8223Y-A-V3"
      }
    ]
  },
  "ASM10": {
    "ASM10": [
      {
        "New Ref Code": "ASM101A"
      }
    ]
  },
  "ASR11": {
    "ASR11": [
      {
        "New Ref Code": "ASR1101M-V1"
      },
      {
        "New Ref Code": "ASR1100B-V1"
      },
      {
        "New Ref Code": "ASR1100B-D-V1"
      },
      {
        "New Ref Code": "ASR1102A(V3)"
      },
      {
        "New Ref Code": "ASR1102A-D(V3)"
      }
    ]
  },
  "ASR21": {
    "ASR21": [
      {
        "New Ref Code": "ASR2101H-D"
      },
      {
        "New Ref Code": "ASR2100H"
      },
      {
        "New Ref Code": "ASR2100H-D"
      },
      {
        "New Ref Code": "ASR2101H"
      },
      {
        "New Ref Code": "ASR2100A"
      },
      {
        "New Ref Code": "ASR2100A-D"
      },
      {
        "New Ref Code": "ASR2101A"
      },
      {
        "New Ref Code": "ASR2101A-D"
      },
      {
        "New Ref Code": "ASR2102A"
      },
      {
        "New Ref Code": "ASR2102A-D"
      },
      {
        "New Ref Code": "ASR2101A-ME"
      }
    ]
  },
  "ASR22": {
    "ASR22": [
      {
        "New Ref Code": "ASR2201A"
      }
    ]
  },
  "AWA62": {
    "AWA62": [
      {
        "New Ref Code": "AWA6220-C"
      },
      {
        "New Ref Code": "AWA6220-O"
      }
    ]
  },
  "AX15M": {
    "AX15M": [
      {
        "New Ref Code": "AX15M"
      }
    ]
  },
  "AX18": {
    "AX18": [
      {
        "New Ref Code": "AX18"
      }
    ]
  },
  "CP902": {
    "CP902": [
      {
        "New Ref Code": "CP902-YG"
      }
    ]
  },
  "CS400": {
    "CS400": [
      {
        "New Ref Code": "CS4006-4GT-60"
      },
      {
        "New Ref Code": "CS4006-4ET-60"
      }
    ]
  },
  "CS401": {
    "CS401": [
      {
        "New Ref Code": "CS4010-8GT-110"
      },
      {
        "New Ref Code": "CS4010-8ET-110"
      }
    ]
  },
  "CS421": {
    "CS421": [
      {
        "New Ref Code": "CS4218-16ET-135"
      },
      {
        "New Ref Code": "CS4218-16ET-190"
      },
      {
        "New Ref Code": "CS4218-16ET-240"
      }
    ]
  },
  "CS422": {
    "CS422": [
      {
        "New Ref Code": "CS4220-16GT-135"
      },
      {
        "New Ref Code": "CS4220-16GT-190"
      },
      {
        "New Ref Code": "CS4220-16GT-240"
      },
      {
        "New Ref Code": "CS4228-24GT-240"
      },
      {
        "New Ref Code": "CS4228-24GT-375"
      },
      {
        "New Ref Code": "CS4226-24ET-240"
      },
      {
        "New Ref Code": "CS4226-24ET-375"
      }
    ]
  },
  "DHL19": {
    "DHL19": [
      {
        "New Ref Code": "DHL19/22/27/32-BG"
      }
    ]
  },
  "DHL42": {
    "DHL42": [
      {
        "New Ref Code": "DHL42/43/49/55-BG"
      }
    ]
  },
  "DSCON": {
    "DSCON": [
      {
        "New Ref Code": "DSCON3000-4U"
      },
      {
        "New Ref Code": "DSCON3000-M"
      }
    ]
  },
  "DSMS0": {
    "DSMS0": [
      {
        "New Ref Code": "DSMS0115EPI-4K"
      }
    ]
  },
  "DSS40": {
    "DSS40": [
      {
        "New Ref Code": "DSS4004-S2"
      }
    ]
  },
  "DSS70": {
    "DSS70": [
      {
        "New Ref Code": "DSS7016D-S2"
      },
      {
        "New Ref Code": "DSS7016DR-S2"
      }
    ]
  },
  "DSS8E": {
    "DSS8E": [
      {
        "New Ref Code": "DSS8EXV"
      },
      {
        "New Ref Code": "DSS8EXD"
      },
      {
        "New Ref Code": "DSS8EXVDP"
      },
      {
        "New Ref Code": "DSS8EXAL"
      },
      {
        "New Ref Code": "DSS8EXVEM"
      },
      {
        "New Ref Code": "DSS8EXMSITE"
      }
    ]
  },
  "DSS8P": {
    "DSS8P": [
      {
        "New Ref Code": "DSS8PRVB"
      },
      {
        "New Ref Code": "DSS8PRDB"
      },
      {
        "New Ref Code": "DSS8PRV"
      },
      {
        "New Ref Code": "DSS8PRD"
      },
      {
        "New Ref Code": "DSS8PRVDP"
      },
      {
        "New Ref Code": "DSS8PRAL"
      },
      {
        "New Ref Code": "DSS8PRPOS"
      },
      {
        "New Ref Code": "DSS8PRRAD"
      },
      {
        "New Ref Code": "DSS8PREMG"
      },
      {
        "New Ref Code": "DSS8PRVEM"
      },
      {
        "New Ref Code": "DSS8PRCS1Y"
      },
      {
        "New Ref Code": "DSS8PRCAC"
      },
      {
        "New Ref Code": "DSS8PRLC"
      },
      {
        "New Ref Code": "DSS8PRBC"
      },
      {
        "New Ref Code": "DSS8PRRML"
      },
      {
        "New Ref Code": "DSS8PREASDL"
      },
      {
        "New Ref Code": "DSS8PRVDPAPP"
      },
      {
        "New Ref Code": "DSS8PRDATABASE"
      },
      {
        "New Ref Code": "DSS8PRSPACE"
      },
      {
        "New Ref Code": "DSS8PRLEDSCREEN"
      },
      {
        "New Ref Code": "DSS8PRWMD"
      },
      {
        "New Ref Code": "DSS8PRSSM"
      },
      {
        "New Ref Code": "DSS8PRGTALK"
      },
      {
        "New Ref Code": "DSS8PRMSITE"
      },
      {
        "New Ref Code": "DSS8PRSOM"
      },
      {
        "New Ref Code": "DSS8PRIIM"
      }
    ]
  },
  "DSSPR": {
    "DSSPR": [
      {
        "New Ref Code": "DSSPR8CLL"
      }
    ]
  },
  "EAC10": {
    "EAC10": [
      {
        "New Ref Code": "EAC10-P"
      }
    ]
  },
  "EAP52": {
    "EAP52": [
      {
        "New Ref Code": "EAP5212-C"
      }
    ]
  },
  "EAP62": {
    "EAP62": [
      {
        "New Ref Code": "EAP6218-W"
      }
    ]
  },
  "ECA2A": {
    "ECA2A": [
      {
        "New Ref Code": "ECA2A1400-HN"
      },
      {
        "New Ref Code": "ECA2A1400-HN"
      }
    ]
  },
  "ECA3A": {
    "ECA3A": [
      {
        "New Ref Code": "ECA3A1404-HNR-XB"
      }
    ]
  },
  "ECA7A": {
    "ECA7A": [
      {
        "New Ref Code": "ECA7A1425-HNR-XA-F"
      }
    ]
  },
  "ECA7B": {
    "ECA7B": [
      {
        "New Ref Code": "ECA7B1231-HNP-XA-F"
      }
    ]
  },
  "EPC23": {
    "EPC23": [
      {
        "New Ref Code": "EPC230U"
      },
      {
        "New Ref Code": "EPC230U-PTZ"
      },
      {
        "New Ref Code": "EPC230U-PTZ-IR"
      }
    ]
  },
  "EPC24": {
    "EPC24": [
      {
        "New Ref Code": "EPC245U-PTZ"
      },
      {
        "New Ref Code": "EPC245U-PTZ-IR"
      }
    ]
  },
  "EVS50": {
    "EVS50": [
      {
        "New Ref Code": "EVS5016S-V2"
      },
      {
        "New Ref Code": "EVS5016S-V2"
      },
      {
        "New Ref Code": "EVS5016S-R-V2"
      }
    ]
  },
  "EVS51": {
    "EVS51": [
      {
        "New Ref Code": "EVS5124S"
      },
      {
        "New Ref Code": "EVS5136S"
      },
      {
        "New Ref Code": "EVS5148S"
      },
      {
        "New Ref Code": "EVS5136S"
      },
      {
        "New Ref Code": "EVS5148S"
      },
      {
        "New Ref Code": "EVS5124S"
      }
    ]
  },
  "EVS71": {
    "EVS71": [
      {
        "New Ref Code": "EVS7124D-V2"
      },
      {
        "New Ref Code": "EVS7148D-V2"
      },
      {
        "New Ref Code": "EVS7124S"
      },
      {
        "New Ref Code": "EVS7148S"
      },
      {
        "New Ref Code": "EVS7124S"
      },
      {
        "New Ref Code": "EVS7136S"
      },
      {
        "New Ref Code": "EVS7148S"
      }
    ]
  },
  "EVS72": {
    "EVS72": [
      {
        "New Ref Code": "EVS7285S"
      },
      {
        "New Ref Code": "EVS7285S"
      }
    ]
  },
  "EVS82": {
    "EVS82": [
      {
        "New Ref Code": "EVS8224X"
      },
      {
        "New Ref Code": "EVS8236X"
      },
      {
        "New Ref Code": "EVS8224X"
      }
    ]
  },
  "FAD20": {
    "FAD20": [
      {
        "New Ref Code": "FAD201A"
      }
    ]
  },
  "H2A": {
    "H2A": [
      {
        "New Ref Code": "H2A"
      }
    ]
  },
  "H2C": {
    "H2C": [
      {
        "New Ref Code": "H2C"
      }
    ]
  },
  "H4A": {
    "H4A": [
      {
        "New Ref Code": "H4A"
      }
    ]
  },
  "H4C": {
    "H4C": [
      {
        "New Ref Code": "H4C"
      }
    ]
  },
  "HMC51": {
    "HMC51": [
      {
        "New Ref Code": "HMC5100X-H-506B1-W10A-BW"
      },
      {
        "New Ref Code": "HMC5100X-H-506C2-W10A-BW"
      }
    ]
  },
  "ILS10": {
    "ILS10": [
      {
        "New Ref Code": "ILS1000"
      }
    ]
  },
  "IPMEC": {
    "IPMEC": [
      {
        "New Ref Code": "IPMECD-R20"
      },
      {
        "New Ref Code": "IPMECD-3022-RM30-T09"
      }
    ]
  },
  "IS420": {
    "IS420": [
      {
        "New Ref Code": "IS4204-2GT-120"
      },
      {
        "New Ref Code": "IS4207-4GT-120"
      }
    ]
  },
  "IS421": {
    "IS421": [
      {
        "New Ref Code": "IS4210-8GT-120"
      }
    ]
  },
  "IS441": {
    "IS441": [
      {
        "New Ref Code": "IS4410-6GT-120"
      }
    ]
  },
  "IS442": {
    "IS442": [
      {
        "New Ref Code": "IS4420-16GT-240"
      }
    ]
  },
  "ITALE": {
    "ITALE": [
      {
        "New Ref Code": "ITALE-160BA-P3525"
      }
    ]
  },
  "ITALF": {
    "ITALF": [
      {
        "New Ref Code": "ITALF-300AD-GS"
      },
      {
        "New Ref Code": "ITALF-300AD-IR"
      },
      {
        "New Ref Code": "ITALF-300AG-F"
      }
    ]
  },
  "ITARD": {
    "ITARD": [
      {
        "New Ref Code": "ITARD-024SA-ST"
      },
      {
        "New Ref Code": "ITARD-024MA-T6"
      }
    ]
  },
  "ITASD": {
    "ITASD": [
      {
        "New Ref Code": "ITASD-020RA"
      }
    ]
  },
  "ITC16": {
    "ITC16": [
      {
        "New Ref Code": "ITC1652-AU5F-LZF1640"
      },
      {
        "New Ref Code": "ITC1652-AU5F-IRL8ZF1640"
      }
    ]
  },
  "ITC35": {
    "ITC35": [
      {
        "New Ref Code": "ITC352-AU3F-LZF1640"
      }
    ]
  },
  "ITC41": {
    "ITC41": [
      {
        "New Ref Code": "ITC413-PW4D-Z1"
      },
      {
        "New Ref Code": "ITC413-PW4D-IZ1"
      },
      {
        "New Ref Code": "ITC413-PW4D-Z3"
      },
      {
        "New Ref Code": "ITC413-PW4D-IZ3"
      },
      {
        "New Ref Code": "ITC413-PW4D-Z1"
      },
      {
        "New Ref Code": "ITC413-PW4D-IZ1"
      },
      {
        "New Ref Code": "ITC413-PW4D-Z3"
      },
      {
        "New Ref Code": "ITC413-PW4D-IZ3"
      },
      {
        "New Ref Code": "ITC415-PW6M-IZ-GN"
      }
    ]
  },
  "ITC43": {
    "ITC43": [
      {
        "New Ref Code": "ITC431-RW1F-IRL8"
      },
      {
        "New Ref Code": "ITC431-RW1F-L"
      },
      {
        "New Ref Code": "ITC431-RW1F-IRL8"
      }
    ]
  },
  "ITC95": {
    "ITC95": [
      {
        "New Ref Code": "ITC952-AU3F-IRL8ZF1640"
      },
      {
        "New Ref Code": "ITC952-SU2F-PQE-C1R1-IRL8ZF1640"
      },
      {
        "New Ref Code": "ITC952-AU3F-LZF1640"
      },
      {
        "New Ref Code": "ITC952-SU2F-GQE-C2R1-IRL8ZF1640"
      }
    ]
  },
  "ITRTS": {
    "ITRTS": [
      {
        "New Ref Code": "ITRTSC-036B-HS"
      },
      {
        "New Ref Code": "ITRTSC-072B-HS"
      }
    ]
  },
  "ITSE1": {
    "ITSE1": [
      {
        "New Ref Code": "ITSE1200-TA-N02"
      },
      {
        "New Ref Code": "ITSE1200-TA-G02"
      }
    ]
  },
  "ITSJC": {
    "ITSJC": [
      {
        "New Ref Code": "ITSJC-2303-DC12"
      }
    ]
  },
  "IVSS7": {
    "IVSS7": [
      {
        "New Ref Code": "IVSS7012"
      },
      {
        "New Ref Code": "IVSS7024-8M"
      },
      {
        "New Ref Code": "IVSS7016DR-8M"
      },
      {
        "New Ref Code": "IVSS7016-8M"
      },
      {
        "New Ref Code": "IVSS7108-2M"
      },
      {
        "New Ref Code": "IVSS7108-1M"
      },
      {
        "New Ref Code": "IVSS7024DR"
      },
      {
        "New Ref Code": "IVSS7024"
      },
      {
        "New Ref Code": "IVSS7016DR"
      },
      {
        "New Ref Code": "IVSS7016"
      },
      {
        "New Ref Code": "IVSS7108"
      }
    ]
  },
  "Infor": {
    "Infor": [
      {
        "New Ref Code": "InformationPublish-Display Channel"
      },
      {
        "New Ref Code": "InformationPublish-Base"
      }
    ]
  },
  "KTA02": {
    "KTA02": [
      {
        "New Ref Code": "KTA02"
      },
      {
        "New Ref Code": "KTA02M"
      }
    ]
  },
  "KTA03": {
    "KTA03": [
      {
        "New Ref Code": "KTA03"
      },
      {
        "New Ref Code": "KTA03M"
      }
    ]
  },
  "KTA04": {
    "KTA04": [
      {
        "New Ref Code": "KTA04"
      }
    ]
  },
  "KTP01": {
    "KTP01": [
      {
        "New Ref Code": "KTP01L(F)"
      },
      {
        "New Ref Code": "KTP01L(S)"
      },
      {
        "New Ref Code": "KTP01(F)"
      },
      {
        "New Ref Code": "KTP01(S)"
      }
    ]
  },
  "KTP02": {
    "KTP02": [
      {
        "New Ref Code": "KTP02"
      }
    ]
  },
  "KTP03": {
    "KTP03": [
      {
        "New Ref Code": "KTP03"
      }
    ]
  },
  "KTP04": {
    "KTP04": [
      {
        "New Ref Code": "KTP04(F)"
      },
      {
        "New Ref Code": "KTP04(S)"
      }
    ]
  },
  "KTW01": {
    "KTW01": [
      {
        "New Ref Code": "KTW01"
      }
    ]
  },
  "KTW02": {
    "KTW02": [
      {
        "New Ref Code": "KTW02"
      }
    ]
  },
  "KTX01": {
    "KTX01": [
      {
        "New Ref Code": "KTX01(S)"
      },
      {
        "New Ref Code": "KTX01(F)"
      }
    ]
  },
  "LPH65": {
    "LPH65": [
      {
        "New Ref Code": "LPH65-MC470-P"
      },
      {
        "New Ref Code": "LPH65-ST470-B"
      }
    ]
  },
  "LPH75": {
    "LPH75": [
      {
        "New Ref Code": "LPH75-MC470-P"
      },
      {
        "New Ref Code": "LPH75-ST470-B"
      }
    ]
  },
  "LPH86": {
    "LPH86": [
      {
        "New Ref Code": "LPH86-MT440-C"
      },
      {
        "New Ref Code": "LPH86-HC411"
      },
      {
        "New Ref Code": "LPH86-MC470-P"
      },
      {
        "New Ref Code": "LPH86-ST470-P"
      }
    ]
  },
  "LPH98": {
    "LPH98": [
      {
        "New Ref Code": "LPH98-MC470-P"
      }
    ]
  },
  "LR211": {
    "LR211": [
      {
        "New Ref Code": "LR2110-8ET-120"
      }
    ]
  },
  "LR221": {
    "LR221": [
      {
        "New Ref Code": "LR2218-16ET-240"
      }
    ]
  },
  "LR222": {
    "LR222": [
      {
        "New Ref Code": "LR2226-24ET-360"
      }
    ]
  },
  "LS460": {
    "LS460": [
      {
        "New Ref Code": "LS460UCM-EF"
      },
      {
        "New Ref Code": "LS460UCM-BF"
      }
    ]
  },
  "LS490": {
    "LS490": [
      {
        "New Ref Code": "LS490UCM-EF"
      },
      {
        "New Ref Code": "LS490UCM-UF"
      }
    ]
  },
  "LS550": {
    "LS550": [
      {
        "New Ref Code": "LS550UCM-EF"
      },
      {
        "New Ref Code": "LS550UCM-BF"
      },
      {
        "New Ref Code": "LS550UCM-BF"
      },
      {
        "New Ref Code": "LS550UEG"
      },
      {
        "New Ref Code": "LS550UDM-EF"
      },
      {
        "New Ref Code": "LS550UCM-UF"
      }
    ]
  },
  "LTV43": {
    "LTV43": [
      {
        "New Ref Code": "LTV43-SN400"
      },
      {
        "New Ref Code": "LTV43-SA200"
      }
    ]
  },
  "MAX18": {
    "MAX18": [
      {
        "New Ref Code": "MAX18"
      },
      {
        "New Ref Code": "MAX18-3"
      }
    ]
  },
  "MNVR8": {
    "MNVR8": [
      {
        "New Ref Code": "MNVR8104-GFWI"
      },
      {
        "New Ref Code": "MNVR8208-GFWI"
      }
    ]
  },
  "N3": {
    "N3": [
      {
        "New Ref Code": "N3"
      }
    ]
  },
  "NKB50": {
    "NKB50": [
      {
        "New Ref Code": "NKB5000-F"
      }
    ]
  },
  "NVD01": {
    "NVD01": [
      {
        "New Ref Code": "NVD01054K"
      }
    ]
  },
  "NVD04": {
    "NVD04": [
      {
        "New Ref Code": "NVD0405DU-2I-8K"
      }
    ]
  },
  "NVD06": {
    "NVD06": [
      {
        "New Ref Code": "NVD06054I-4K"
      }
    ]
  },
  "NVD09": {
    "NVD09": [
      {
        "New Ref Code": "NVD09054I-4K"
      }
    ]
  },
  "NVD12": {
    "NVD12": [
      {
        "New Ref Code": "NVD12054I-4K"
      }
    ]
  },
  "NVD15": {
    "NVD15": [
      {
        "New Ref Code": "NVD15054I-4K"
      }
    ]
  },
  "NVD18": {
    "NVD18": [
      {
        "New Ref Code": "NVD18054I-4K"
      }
    ]
  },
  "NVD21": {
    "NVD21": [
      {
        "New Ref Code": "NVD21054I-4K"
      }
    ]
  },
  "NVR11": {
    "NVR11": [
      {
        "New Ref Code": "NVR1104HS-W-S2-CE"
      },
      {
        "New Ref Code": "NVR1108HS-W-S2-CE"
      },
      {
        "New Ref Code": "NVR1104HS-S3/H"
      },
      {
        "New Ref Code": "NVR1108HS-S3/H"
      },
      {
        "New Ref Code": "NVR1104HS-P-S3/H"
      },
      {
        "New Ref Code": "NVR1108HS-8P-S3/H"
      }
    ]
  },
  "NVR21": {
    "NVR21": [
      {
        "New Ref Code": "NVR2104HS-I2"
      },
      {
        "New Ref Code": "NVR2108HS-I2"
      },
      {
        "New Ref Code": "NVR2116HS-I2"
      },
      {
        "New Ref Code": "NVR2104-I2"
      },
      {
        "New Ref Code": "NVR2108-I2"
      },
      {
        "New Ref Code": "NVR2116-I2"
      },
      {
        "New Ref Code": "NVR2104-P-I2"
      },
      {
        "New Ref Code": "NVR2104HS-P-I2"
      },
      {
        "New Ref Code": "NVR2108-8P-I2"
      },
      {
        "New Ref Code": "NVR2108HS-8P-I2"
      },
      {
        "New Ref Code": "NVR2108HS-8P-4KS2"
      },
      {
        "New Ref Code": "NVR2104-S3"
      },
      {
        "New Ref Code": "NVR2108-S3"
      },
      {
        "New Ref Code": "NVR2116-S3"
      },
      {
        "New Ref Code": "NVR2104HS-S3"
      },
      {
        "New Ref Code": "NVR2108HS-S3"
      },
      {
        "New Ref Code": "NVR2116HS-S3"
      },
      {
        "New Ref Code": "NVR2104-P-S3"
      },
      {
        "New Ref Code": "NVR2108-8P-S3"
      },
      {
        "New Ref Code": "NVR2104HS-P-S3"
      },
      {
        "New Ref Code": "NVR2108HS-8P-S3"
      }
    ]
  },
  "NVR22": {
    "NVR22": [
      {
        "New Ref Code": "NVR2204-I2"
      },
      {
        "New Ref Code": "NVR2208-I2"
      },
      {
        "New Ref Code": "NVR2216-I2"
      },
      {
        "New Ref Code": "NVR2204-P-I2"
      },
      {
        "New Ref Code": "NVR2208-8P-I2"
      },
      {
        "New Ref Code": "NVR2216-16P-I2"
      }
    ]
  },
  "NVR41": {
    "NVR41": [
      {
        "New Ref Code": "NVR4116HS-EI"
      },
      {
        "New Ref Code": "NVR4104HS-P-EI"
      },
      {
        "New Ref Code": "NVR4108HS-8P-EI"
      },
      {
        "New Ref Code": "NVR4116-8P-4KS3"
      },
      {
        "New Ref Code": "NVR4116HS-8P-4KS3"
      },
      {
        "New Ref Code": "NVR4108-4KS3"
      },
      {
        "New Ref Code": "NVR4116-4KS3"
      },
      {
        "New Ref Code": "NVR4108HS-4KS3"
      },
      {
        "New Ref Code": "NVR4116HS-4KS3"
      },
      {
        "New Ref Code": "NVR4108-P-4KS3"
      },
      {
        "New Ref Code": "NVR4108HS-P-4KS3"
      },
      {
        "New Ref Code": "NVR4104-4KS3"
      },
      {
        "New Ref Code": "NVR4104HS-4KS3"
      },
      {
        "New Ref Code": "NVR4104-P-4KS3"
      },
      {
        "New Ref Code": "NVR4104HS-P-4KS3"
      },
      {
        "New Ref Code": "NVR4108-8P-4KS3"
      },
      {
        "New Ref Code": "NVR4108HS-8P-4KS3"
      },
      {
        "New Ref Code": "NVR4116HS-8P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4108HS-8P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4108HS-P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4104HS-P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4116HS-4KS2/L"
      },
      {
        "New Ref Code": "NVR4108HS-4KS2/L"
      },
      {
        "New Ref Code": "NVR4104HS-4KS2/L"
      },
      {
        "New Ref Code": "NVR4116-8P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4108-8P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4108-P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4104-P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4116-4KS2/L"
      },
      {
        "New Ref Code": "NVR4108-4KS2/L"
      },
      {
        "New Ref Code": "NVR4104-4KS2/L"
      }
    ]
  },
  "NVR42": {
    "NVR42": [
      {
        "New Ref Code": "NVR4208-EI"
      },
      {
        "New Ref Code": "NVR4216-EI"
      },
      {
        "New Ref Code": "NVR4216-16P-EI"
      },
      {
        "New Ref Code": "NVR4232-16P-4KS3"
      },
      {
        "New Ref Code": "NVR4204-P-4KS3"
      },
      {
        "New Ref Code": "NVR4208-8P-4KS3"
      },
      {
        "New Ref Code": "NVR4232-4KS3"
      },
      {
        "New Ref Code": "NVR4216-16P-4KS3"
      },
      {
        "New Ref Code": "NVR4216-4KS3"
      },
      {
        "New Ref Code": "NVR4208-4KS3"
      },
      {
        "New Ref Code": "NVR4204-4KS3"
      },
      {
        "New Ref Code": "NVR4216-16P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4208-8P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4204-P-4KS2/L"
      },
      {
        "New Ref Code": "NVR4216-4KS2/L"
      },
      {
        "New Ref Code": "NVR4208-4KS2/L"
      },
      {
        "New Ref Code": "NVR4204-4KS2/L"
      },
      {
        "New Ref Code": "NVR4232-4KS2/L"
      },
      {
        "New Ref Code": "NVR4232-16P-4KS2/L"
      }
    ]
  },
  "NVR50": {
    "NVR50": [
      {
        "New Ref Code": "NVR5064-EI"
      },
      {
        "New Ref Code": "NVR5016-EI"
      },
      {
        "New Ref Code": "NVR5032-EI"
      }
    ]
  },
  "NVR52": {
    "NVR52": [
      {
        "New Ref Code": "NVR5232-EI"
      },
      {
        "New Ref Code": "NVR5232-8P-EI"
      },
      {
        "New Ref Code": "NVR5232-16P-EI"
      },
      {
        "New Ref Code": "NVR5208-EI"
      },
      {
        "New Ref Code": "NVR5216-EI"
      },
      {
        "New Ref Code": "NVR5208-8P-EI"
      },
      {
        "New Ref Code": "NVR5216-8P-EI"
      },
      {
        "New Ref Code": "NVR5216-16P-EI"
      }
    ]
  },
  "NVR54": {
    "NVR54": [
      {
        "New Ref Code": "NVR5464-EI"
      },
      {
        "New Ref Code": "NVR5464-16P-EI"
      },
      {
        "New Ref Code": "NVR5416-EI"
      },
      {
        "New Ref Code": "NVR5432-EI"
      },
      {
        "New Ref Code": "NVR5416-16P-EI"
      },
      {
        "New Ref Code": "NVR5432-16P-EI"
      }
    ]
  },
  "NVR58": {
    "NVR58": [
      {
        "New Ref Code": "NVR5864-EI"
      },
      {
        "New Ref Code": "NVR5864-16P-EI"
      },
      {
        "New Ref Code": "NVR5816-EI"
      },
      {
        "New Ref Code": "NVR5832-EI"
      },
      {
        "New Ref Code": "NVR5816-16P-EI"
      },
      {
        "New Ref Code": "NVR5832-16P-EI"
      }
    ]
  },
  "NVR60": {
    "NVR60": [
      {
        "New Ref Code": "NVR608H-64-XI"
      },
      {
        "New Ref Code": "NVR608RH-128-XI"
      },
      {
        "New Ref Code": "NVR608H-32-XI"
      },
      {
        "New Ref Code": "NVR608H-128-XI"
      },
      {
        "New Ref Code": "NVR608RH-32-XI"
      },
      {
        "New Ref Code": "NVR608RH-64-XI"
      }
    ]
  },
  "NVR61": {
    "NVR61": [
      {
        "New Ref Code": "NVR616RH-128-XI"
      },
      {
        "New Ref Code": "NVR616-128-4KS2"
      }
    ]
  },
  "PFA10": {
    "PFA10": [
      {
        "New Ref Code": "PFA109-B"
      },
      {
        "New Ref Code": "PFA100"
      },
      {
        "New Ref Code": "PFA101"
      },
      {
        "New Ref Code": "PFA102"
      },
      {
        "New Ref Code": "PFA103"
      },
      {
        "New Ref Code": "PFA105"
      },
      {
        "New Ref Code": "PFA106"
      },
      {
        "New Ref Code": "PFA107"
      },
      {
        "New Ref Code": "PFA108"
      },
      {
        "New Ref Code": "PFA109"
      },
      {
        "New Ref Code": "PFA10C"
      }
    ]
  },
  "PFA11": {
    "PFA11": [
      {
        "New Ref Code": "PFA117-B"
      },
      {
        "New Ref Code": "PFA112"
      },
      {
        "New Ref Code": "PFA113"
      },
      {
        "New Ref Code": "PFA117"
      }
    ]
  },
  "PFA12": {
    "PFA12": [
      {
        "New Ref Code": "PFA12A"
      },
      {
        "New Ref Code": "PFA120"
      },
      {
        "New Ref Code": "PFA121"
      },
      {
        "New Ref Code": "PFA122"
      },
      {
        "New Ref Code": "PFA123"
      },
      {
        "New Ref Code": "PFA124-B"
      },
      {
        "New Ref Code": "PFA126"
      },
      {
        "New Ref Code": "PFA12C"
      },
      {
        "New Ref Code": "PFA120-SG"
      },
      {
        "New Ref Code": "PFA121-B"
      },
      {
        "New Ref Code": "PFA122-B"
      },
      {
        "New Ref Code": "PFA120A"
      },
      {
        "New Ref Code": "PFA121A"
      }
    ]
  },
  "PFA13": {
    "PFA13": [
      {
        "New Ref Code": "PFA135-B"
      },
      {
        "New Ref Code": "PFA130-E"
      },
      {
        "New Ref Code": "PFA132-E"
      },
      {
        "New Ref Code": "PFA133-E"
      },
      {
        "New Ref Code": "PFA134"
      },
      {
        "New Ref Code": "PFA135"
      },
      {
        "New Ref Code": "PFA136"
      },
      {
        "New Ref Code": "PFA137"
      },
      {
        "New Ref Code": "PFA138"
      },
      {
        "New Ref Code": "PFA139"
      },
      {
        "New Ref Code": "PFA13A-E"
      },
      {
        "New Ref Code": "PFA13F"
      },
      {
        "New Ref Code": "PFA13G"
      },
      {
        "New Ref Code": "PFA130-E-B"
      },
      {
        "New Ref Code": "PFA134-B"
      },
      {
        "New Ref Code": "PFA136-B"
      },
      {
        "New Ref Code": "PFA137-B"
      },
      {
        "New Ref Code": "PFA139-B"
      },
      {
        "New Ref Code": "PFA130A-E"
      }
    ]
  },
  "PFA14": {
    "PFA14": [
      {
        "New Ref Code": "PFA140"
      },
      {
        "New Ref Code": "PFA141"
      },
      {
        "New Ref Code": "PFA143"
      }
    ]
  },
  "PFA15": {
    "PFA15": [
      {
        "New Ref Code": "PFA156-B"
      },
      {
        "New Ref Code": "PFA150-T"
      },
      {
        "New Ref Code": "PFA150"
      },
      {
        "New Ref Code": "PFA152-E"
      },
      {
        "New Ref Code": "PFA153"
      },
      {
        "New Ref Code": "PFA154"
      },
      {
        "New Ref Code": "PFA151"
      },
      {
        "New Ref Code": "PFA157"
      },
      {
        "New Ref Code": "PFA156"
      },
      {
        "New Ref Code": "PFA150-SG"
      },
      {
        "New Ref Code": "PFA153-SG"
      },
      {
        "New Ref Code": "PFA150-B"
      },
      {
        "New Ref Code": "PFA152-E-B"
      },
      {
        "New Ref Code": "PFA151-B"
      },
      {
        "New Ref Code": "PFA155A"
      },
      {
        "New Ref Code": "PFA152A-E"
      },
      {
        "New Ref Code": "PFA153A"
      }
    ]
  },
  "PFA16": {
    "PFA16": [
      {
        "New Ref Code": "PFA162"
      },
      {
        "New Ref Code": "PFA162-SG"
      }
    ]
  },
  "PFA19": {
    "PFA19": [
      {
        "New Ref Code": "PFA197R-B"
      },
      {
        "New Ref Code": "PFA197R"
      }
    ]
  },
  "PFA20": {
    "PFA20": [
      {
        "New Ref Code": "PFA200G"
      },
      {
        "New Ref Code": "PFA200W"
      }
    ]
  },
  "PFA77": {
    "PFA77": [
      {
        "New Ref Code": "PFA773"
      }
    ]
  },
  "PFB11": {
    "PFB11": [
      {
        "New Ref Code": "PFB110W"
      },
      {
        "New Ref Code": "PFB110C-E"
      }
    ]
  },
  "PFB12": {
    "PFB12": [
      {
        "New Ref Code": "PFB121W"
      }
    ]
  },
  "PFB20": {
    "PFB20": [
      {
        "New Ref Code": "PFB206W-B"
      },
      {
        "New Ref Code": "PFB203W"
      },
      {
        "New Ref Code": "PFB204W"
      },
      {
        "New Ref Code": "PFB205W-E-G"
      },
      {
        "New Ref Code": "PFB205W-E"
      },
      {
        "New Ref Code": "PFB205W-E-B"
      },
      {
        "New Ref Code": "PFB206W"
      },
      {
        "New Ref Code": "PFB200C"
      },
      {
        "New Ref Code": "PFB203W-B"
      },
      {
        "New Ref Code": "PFB204W-B"
      }
    ]
  },
  "PFB21": {
    "PFB21": [
      {
        "New Ref Code": "PFB211W"
      }
    ]
  },
  "PFB22": {
    "PFB22": [
      {
        "New Ref Code": "PFB220C-B"
      },
      {
        "New Ref Code": "PFB220C"
      }
    ]
  },
  "PFB30": {
    "PFB30": [
      {
        "New Ref Code": "PFB300S"
      },
      {
        "New Ref Code": "PFB302S"
      },
      {
        "New Ref Code": "PFB303W"
      },
      {
        "New Ref Code": "PFB305W"
      },
      {
        "New Ref Code": "PFB306W"
      },
      {
        "New Ref Code": "PFB300C"
      },
      {
        "New Ref Code": "PFB301C"
      },
      {
        "New Ref Code": "PFB301S-E"
      },
      {
        "New Ref Code": "PFB303S"
      },
      {
        "New Ref Code": "PFB300CA"
      }
    ]
  },
  "PFB31": {
    "PFB31": [
      {
        "New Ref Code": "PFB310W"
      }
    ]
  },
  "PFB41": {
    "PFB41": [
      {
        "New Ref Code": "PFB414W"
      }
    ]
  },
  "PFB51": {
    "PFB51": [
      {
        "New Ref Code": "PFB510W"
      }
    ]
  },
  "PFB60": {
    "PFB60": [
      {
        "New Ref Code": "PFB603W"
      },
      {
        "New Ref Code": "PFB605W-SG"
      },
      {
        "New Ref Code": "PFB604WA"
      },
      {
        "New Ref Code": "PFB604W"
      },
      {
        "New Ref Code": "PFB605W"
      },
      {
        "New Ref Code": "PFB600W"
      },
      {
        "New Ref Code": "PFB601W"
      },
      {
        "New Ref Code": "PFB603C"
      }
    ]
  },
  "PFB71": {
    "PFB71": [
      {
        "New Ref Code": "PFB714W"
      }
    ]
  },
  "PFC10": {
    "PFC10": [
      {
        "New Ref Code": "PFC102F"
      }
    ]
  },
  "PFC20": {
    "PFC20": [
      {
        "New Ref Code": "PFC200D-6U4D"
      },
      {
        "New Ref Code": "PFC200D-9U4D"
      },
      {
        "New Ref Code": "PFC200D-12U4D"
      },
      {
        "New Ref Code": "PFC200D-18U6D"
      },
      {
        "New Ref Code": "PFC200D-42U8D"
      }
    ]
  },
  "PFC61": {
    "PFC61": [
      {
        "New Ref Code": "PFC610-4D"
      },
      {
        "New Ref Code": "PFC610-6D"
      },
      {
        "New Ref Code": "PFC610-8D"
      }
    ]
  },
  "PFH61": {
    "PFH61": [
      {
        "New Ref Code": "PFH610A-IR-W-POE"
      },
      {
        "New Ref Code": "PFH610V-H-POE"
      },
      {
        "New Ref Code": "PFH610A-H-POE"
      },
      {
        "New Ref Code": "PFH610V-IR-POE"
      },
      {
        "New Ref Code": "PFH610V"
      },
      {
        "New Ref Code": "PFH610A"
      }
    ]
  },
  "PFL10": {
    "PFL10": [
      {
        "New Ref Code": "PFL1040-A12PE"
      },
      {
        "New Ref Code": "PFL1040-K9PE"
      }
    ]
  },
  "PFL12": {
    "PFL12": [
      {
        "New Ref Code": "PFL12-K10M"
      }
    ]
  },
  "PFL15": {
    "PFL15": [
      {
        "New Ref Code": "PFL1575-A12D"
      }
    ]
  },
  "PFL16": {
    "PFL16": [
      {
        "New Ref Code": "PFL1640-L12PE"
      }
    ]
  },
  "PFL25": {
    "PFL25": [
      {
        "New Ref Code": "PFL25-L12M"
      }
    ]
  },
  "PFL27": {
    "PFL27": [
      {
        "New Ref Code": "PFL2712-E6D"
      }
    ]
  },
  "PFL35": {
    "PFL35": [
      {
        "New Ref Code": "PFL35-K10M"
      }
    ]
  },
  "PFL50": {
    "PFL50": [
      {
        "New Ref Code": "PFL50-L12M"
      }
    ]
  },
  "PFM30": {
    "PFM30": [
      {
        "New Ref Code": "PFM300"
      }
    ]
  },
  "PFM32": {
    "PFM32": [
      {
        "New Ref Code": "PFM320-010EN"
      },
      {
        "New Ref Code": "PFM320-020EN"
      },
      {
        "New Ref Code": "PFM321D-EN"
      },
      {
        "New Ref Code": "PFM320D-EN"
      },
      {
        "New Ref Code": "PFM320D-BS"
      }
    ]
  },
  "PFM34": {
    "PFM34": [
      {
        "New Ref Code": "PFM340-5CH"
      },
      {
        "New Ref Code": "PFM341-9CH"
      },
      {
        "New Ref Code": "PFM342-9CH"
      },
      {
        "New Ref Code": "PFM343-19CH"
      }
    ]
  },
  "PFM35": {
    "PFM35": [
      {
        "New Ref Code": "PFM350-360"
      },
      {
        "New Ref Code": "PFM350-900"
      }
    ]
  },
  "PFM37": {
    "PFM37": [
      {
        "New Ref Code": "PFM377"
      },
      {
        "New Ref Code": "PFM376-G"
      }
    ]
  },
  "PFM52": {
    "PFM52": [
      {
        "New Ref Code": "PFM522P-D1-IR"
      }
    ]
  },
  "PFM80": {
    "PFM80": [
      {
        "New Ref Code": "PFM800-E"
      },
      {
        "New Ref Code": "PFM800-4K"
      },
      {
        "New Ref Code": "PFM800B-4K"
      }
    ]
  },
  "PFM90": {
    "PFM90": [
      {
        "New Ref Code": "PFM900-E"
      },
      {
        "New Ref Code": "PFM904"
      },
      {
        "New Ref Code": "PFM907-E"
      }
    ]
  },
  "PFM92": {
    "PFM92": [
      {
        "New Ref Code": "PFM922I-6UN-C"
      },
      {
        "New Ref Code": "PFM920I-5EF-C"
      },
      {
        "New Ref Code": "PFM920-6U"
      },
      {
        "New Ref Code": "PFM920-5EU"
      },
      {
        "New Ref Code": "PFM920I-6UN-CN"
      },
      {
        "New Ref Code": "PFM920I-6UN-C"
      },
      {
        "New Ref Code": "PFM920I-6U-C"
      },
      {
        "New Ref Code": "PFM920I-6U-U"
      },
      {
        "New Ref Code": "PFM923I-6UN-C"
      },
      {
        "New Ref Code": "PFM922I-6UN-C"
      },
      {
        "New Ref Code": "PFM922I-6UN-C"
      },
      {
        "New Ref Code": "PFM922I-6UN-C"
      },
      {
        "New Ref Code": "PFM920I-6U-C-100"
      },
      {
        "New Ref Code": "PFM920I-6UN-C"
      }
    ]
  },
  "PFM93": {
    "PFM93": [
      {
        "New Ref Code": "PFM930-59N-100"
      },
      {
        "New Ref Code": "PFM930-59N-200"
      }
    ]
  },
  "PFM94": {
    "PFM94": [
      {
        "New Ref Code": "PFM940I-59N/2"
      },
      {
        "New Ref Code": "PFM942I-20-3"
      },
      {
        "New Ref Code": "PFM942I-10-5"
      },
      {
        "New Ref Code": "PFM942I-20-5"
      },
      {
        "New Ref Code": "PFM942I-30-5"
      }
    ]
  },
  "PFM97": {
    "PFM97": [
      {
        "New Ref Code": "PFM976-631-PT"
      },
      {
        "New Ref Code": "PFM972-6U-1"
      },
      {
        "New Ref Code": "PFM972-6U-3"
      },
      {
        "New Ref Code": "PFM972-6U-1"
      }
    ]
  },
  "PFR4K": {
    "PFR4K": [
      {
        "New Ref Code": "PFR4K-D300"
      },
      {
        "New Ref Code": "PFR4K-D450"
      }
    ]
  },
  "PFR5Q": {
    "PFR5Q": [
      {
        "New Ref Code": "PFR5QI-E60-PV"
      },
      {
        "New Ref Code": "PFR5QI-E60"
      }
    ]
  },
  "PFS30": {
    "PFS30": [
      {
        "New Ref Code": "PFS3016-16GT-190"
      },
      {
        "New Ref Code": "PFS3009-8ET-96"
      },
      {
        "New Ref Code": "PFS3005-4GT-36"
      },
      {
        "New Ref Code": "PFS3010-8GT-65"
      },
      {
        "New Ref Code": "PFS3005-5ET-L"
      },
      {
        "New Ref Code": "PFS3005-5ET"
      },
      {
        "New Ref Code": "PFS3008-8ET-L"
      },
      {
        "New Ref Code": "PFS3008-8ET"
      },
      {
        "New Ref Code": "PFS3005-5GT-L"
      },
      {
        "New Ref Code": "PFS3005-5GT"
      },
      {
        "New Ref Code": "PFS3008-8GT-L"
      },
      {
        "New Ref Code": "PFS3008-8GT"
      },
      {
        "New Ref Code": "PFS3005-4ET-36"
      },
      {
        "New Ref Code": "PFS3006-4ET-36"
      },
      {
        "New Ref Code": "PFS3005-4ET-60"
      },
      {
        "New Ref Code": "PFS3006-4ET-60"
      },
      {
        "New Ref Code": "PFS3006-4GT-60"
      },
      {
        "New Ref Code": "PFS3008-8ET-60"
      },
      {
        "New Ref Code": "PFS3008-8GT-60"
      },
      {
        "New Ref Code": "PFS3009-8ET-65"
      },
      {
        "New Ref Code": "PFS3009-8ET1GT-96"
      },
      {
        "New Ref Code": "PFS3010-8ET-65"
      },
      {
        "New Ref Code": "PFS3010-8ET-96"
      },
      {
        "New Ref Code": "PFS3010-8GT-96"
      },
      {
        "New Ref Code": "PFS3008-8GT-96"
      },
      {
        "New Ref Code": "PFS3008-8GT-L"
      },
      {
        "New Ref Code": "PFS3005-5GT-L"
      },
      {
        "New Ref Code": "PFS3008-8ET-L"
      },
      {
        "New Ref Code": "PFS3005-5ET-L"
      },
      {
        "New Ref Code": "PFS3008-8GT"
      },
      {
        "New Ref Code": "PFS3016-16GT"
      },
      {
        "New Ref Code": "PFS3024-24GT"
      }
    ]
  },
  "PFS31": {
    "PFS31": [
      {
        "New Ref Code": "PFS3110-8ET1GT1GF-96"
      },
      {
        "New Ref Code": "PFS3110-8GT-65"
      },
      {
        "New Ref Code": "PFS3117-16ET-135"
      },
      {
        "New Ref Code": "PFS3111-8ET-96-F"
      },
      {
        "New Ref Code": "PFS3103-1GT1ET-60"
      },
      {
        "New Ref Code": "PFS3106-4ET-60"
      },
      {
        "New Ref Code": "PFS3110-8ET-96"
      },
      {
        "New Ref Code": "PFS3106-4T"
      },
      {
        "New Ref Code": "PFS3110-8T"
      },
      {
        "New Ref Code": "PFS3102-1T"
      }
    ]
  },
  "PFS32": {
    "PFS32": [
      {
        "New Ref Code": "PFS3211-8GT"
      },
      {
        "New Ref Code": "PFS3220-16GT-190"
      },
      {
        "New Ref Code": "PFS3220-16GT-240"
      },
      {
        "New Ref Code": "PFS3228-24GT-240"
      },
      {
        "New Ref Code": "PFS3228-24GT-360"
      },
      {
        "New Ref Code": "PFS3210-8ET2GF-96"
      },
      {
        "New Ref Code": "PFS3210-8GT2GF-96"
      },
      {
        "New Ref Code": "PFS3218-16GT-135"
      },
      {
        "New Ref Code": "PFS3218-16ET-135"
      },
      {
        "New Ref Code": "PFS3226-24ET-240"
      },
      {
        "New Ref Code": "PFS3206-4P-96"
      },
      {
        "New Ref Code": "PFS3206-4P-120"
      },
      {
        "New Ref Code": "PFS3211-8GT-120"
      },
      {
        "New Ref Code": "PFS3211-8GT"
      }
    ]
  },
  "PFS34": {
    "PFS34": [
      {
        "New Ref Code": "PFS3409-4GT"
      },
      {
        "New Ref Code": "PFS3409-4GT-96"
      },
      {
        "New Ref Code": "PFS3409-4GT"
      }
    ]
  },
  "PFS42": {
    "PFS42": [
      {
        "New Ref Code": "PFS4218-16ET-240"
      },
      {
        "New Ref Code": "PFS4218-16ET-190"
      },
      {
        "New Ref Code": "PFS4226-24ET-240"
      },
      {
        "New Ref Code": "PFS4226-24ET-360"
      },
      {
        "New Ref Code": "PFS4218-16GT-130"
      },
      {
        "New Ref Code": "PFS4226-24GT-230"
      },
      {
        "New Ref Code": "PFS4210-8GT-150"
      },
      {
        "New Ref Code": "PFS4218-16GT-190"
      },
      {
        "New Ref Code": "PFS4218-16GT-240"
      },
      {
        "New Ref Code": "PFS4226-24GT-240"
      },
      {
        "New Ref Code": "PFS4210-8GT-DP"
      }
    ]
  },
  "PFS44": {
    "PFS44": [
      {
        "New Ref Code": "PFS4420-16GT-240"
      },
      {
        "New Ref Code": "PFS4428-24GT-370"
      }
    ]
  },
  "PFS59": {
    "PFS59": [
      {
        "New Ref Code": "PFS5936-24GF8GT4XF"
      }
    ]
  },
  "PFWB5": {
    "PFWB5": [
      {
        "New Ref Code": "PFWB5-30ac"
      },
      {
        "New Ref Code": "PFWB5-10ac"
      },
      {
        "New Ref Code": "PFWB5-90ac"
      },
      {
        "New Ref Code": "PFWB5-30n"
      },
      {
        "New Ref Code": "PFWB5-10n"
      },
      {
        "New Ref Code": "PFWB5-90n"
      }
    ]
  },
  "PLZ20": {
    "PLZ20": [
      {
        "New Ref Code": "PLZ20C0-D"
      }
    ]
  },
  "PLZ21": {
    "PLZ21": [
      {
        "New Ref Code": "PLZ21C0-P"
      }
    ]
  },
  "PSDW5": {
    "PSDW5": [
      {
        "New Ref Code": "PSDW5631SP-B360"
      }
    ]
  },
  "PTZ19": {
    "PTZ19": [
      {
        "New Ref Code": "PTZ19245U-IRB-N-B"
      }
    ]
  },
  "PTZ37": {
    "PTZ37": [
      {
        "New Ref Code": "PTZ37225-HNP-XB-A-EG"
      }
    ]
  },
  "PTZ83": {
    "PTZ83": [
      {
        "New Ref Code": "PTZ83440-HNF-PA"
      }
    ]
  },
  "PTZ85": {
    "PTZ85": [
      {
        "New Ref Code": "PTZ85848-HNF-PA-FL"
      },
      {
        "New Ref Code": "PTZ85448-HNF-PA-FL"
      },
      {
        "New Ref Code": "PTZ85848-HNF-PA"
      },
      {
        "New Ref Code": "PTZ85260-HNF-PA"
      }
    ]
  },
  "S4100": {
    "S4100": [
      {
        "New Ref Code": "S4100-8ET2GT-96-C"
      },
      {
        "New Ref Code": "S4100-4ET2ET-60-C"
      },
      {
        "New Ref Code": "S4100-4GT2GT-60-C"
      },
      {
        "New Ref Code": "S4100-8GT1GT-96-C"
      }
    ]
  },
  "S4101": {
    "S4101": [
      {
        "New Ref Code": "S4101-16ET2GF-240-C"
      },
      {
        "New Ref Code": "S4101-24ET2GF-360-C"
      }
    ]
  },
  "S4220": {
    "S4220": [
      {
        "New Ref Code": "S4220-16GT-240"
      },
      {
        "New Ref Code": "S4220-16GT-190"
      }
    ]
  },
  "S4228": {
    "S4228": [
      {
        "New Ref Code": "S4228-24GT-240"
      },
      {
        "New Ref Code": "S4228-24GT-360"
      }
    ]
  },
  "S5500": {
    "S5500": [
      {
        "New Ref Code": "S5500-48GT4XF-E"
      },
      {
        "New Ref Code": "S5500-24GF4XF-E"
      }
    ]
  },
  "S5600": {
    "S5600": [
      {
        "New Ref Code": "S5600-48GT4XF"
      }
    ]
  },
  "S6500": {
    "S6500": [
      {
        "New Ref Code": "S6500-48XF2QF"
      }
    ]
  },
  "S7803": {
    "S7803": [
      {
        "New Ref Code": "S7803"
      }
    ]
  },
  "S7806": {
    "S7806": [
      {
        "New Ref Code": "S7806"
      }
    ]
  },
  "S8610": {
    "S8610": [
      {
        "New Ref Code": "S8610-PWR1200"
      }
    ]
  },
  "SD1A2": {
    "SD1A2": [
      {
        "New Ref Code": "SD1A203T-GN"
      },
      {
        "New Ref Code": "SD1A203T-GN-W"
      }
    ]
  },
  "SD1A4": {
    "SD1A4": [
      {
        "New Ref Code": "SD1A404XB-GNR"
      },
      {
        "New Ref Code": "SD1A404XB-GNR-W"
      }
    ]
  },
  "SD222": {
    "SD222": [
      {
        "New Ref Code": "SD22204DB-GNY"
      },
      {
        "New Ref Code": "SD22204DB-GNY-W"
      },
      {
        "New Ref Code": "SD22204DB-GC"
      }
    ]
  },
  "SD224": {
    "SD224": [
      {
        "New Ref Code": "SD22404DB-GNY"
      }
    ]
  },
  "SD292": {
    "SD292": [
      {
        "New Ref Code": "SD29204UE-GN"
      },
      {
        "New Ref Code": "SD29204UE-GN-W"
      }
    ]
  },
  "SD2A2": {
    "SD2A2": [
      {
        "New Ref Code": "SD2A200HB-GN-A-PV-S2"
      },
      {
        "New Ref Code": "SD2A200HB-GN-AW-PV-S2"
      }
    ]
  },
  "SD2A4": {
    "SD2A4": [
      {
        "New Ref Code": "SD2A400HB-GN-AGQ-PV-SP-EAU"
      }
    ]
  },
  "SD2A5": {
    "SD2A5": [
      {
        "New Ref Code": "SD2A500HB-GN-A-PV-S2"
      },
      {
        "New Ref Code": "SD2A500HB-GN-AW-PV-S2"
      }
    ]
  },
  "SD3A2": {
    "SD3A2": [
      {
        "New Ref Code": "SD3A200-GN-A-PV"
      },
      {
        "New Ref Code": "SD3A205-GNP-PV"
      }
    ]
  },
  "SD3A4": {
    "SD3A4": [
      {
        "New Ref Code": "SD3A405-GN-PV1"
      },
      {
        "New Ref Code": "SD3A400-GN-A-PV"
      }
    ]
  },
  "SD3E4": {
    "SD3E4": [
      {
        "New Ref Code": "SD3E405DB-GNY-A-PV1"
      }
    ]
  },
  "SD402": {
    "SD402": [
      {
        "New Ref Code": "SD40215-HC-LA"
      }
    ]
  },
  "SD422": {
    "SD422": [
      {
        "New Ref Code": "SD42215-HC-LA"
      }
    ]
  },
  "SD42C": {
    "SD42C": [
      {
        "New Ref Code": "SD42C215-HC-LA"
      }
    ]
  },
  "SD492": {
    "SD492": [
      {
        "New Ref Code": "SD49225DB-HNY"
      },
      {
        "New Ref Code": "SD49216DB-HNY"
      },
      {
        "New Ref Code": "SD49225GB-HNR"
      },
      {
        "New Ref Code": "SD49225DB-HC"
      }
    ]
  },
  "SD494": {
    "SD494": [
      {
        "New Ref Code": "SD49425GB-HNR"
      }
    ]
  },
  "SD498": {
    "SD498": [
      {
        "New Ref Code": "SD49825GB-HNR"
      }
    ]
  },
  "SD4A4": {
    "SD4A4": [
      {
        "New Ref Code": "SD4A425DB-HNY"
      }
    ]
  },
  "SD502": {
    "SD502": [
      {
        "New Ref Code": "SD50225DB-HNY"
      },
      {
        "New Ref Code": "SD50232GB-HNR"
      },
      {
        "New Ref Code": "SD50230U-HNI"
      },
      {
        "New Ref Code": "SD50232-HC-LA"
      }
    ]
  },
  "SD504": {
    "SD504": [
      {
        "New Ref Code": "SD50432GB-HNR"
      },
      {
        "New Ref Code": "SD50432XA-HNR"
      }
    ]
  },
  "SD52C": {
    "SD52C": [
      {
        "New Ref Code": "SD52C232GB-HNR"
      },
      {
        "New Ref Code": "SD52C432GB-HNR"
      },
      {
        "New Ref Code": "SD52C225U-HNI"
      },
      {
        "New Ref Code": "SD52C232-HC-LA"
      }
    ]
  },
  "SD592": {
    "SD592": [
      {
        "New Ref Code": "SD59232-HC-LA"
      }
    ]
  },
  "SD5A2": {
    "SD5A2": [
      {
        "New Ref Code": "SD5A225GB-HNR"
      },
      {
        "New Ref Code": "SD5A225GB-HNR-SL"
      },
      {
        "New Ref Code": "SD5A232GB-HNR"
      },
      {
        "New Ref Code": "SD5A245GB-HNR"
      }
    ]
  },
  "SD5A4": {
    "SD5A4": [
      {
        "New Ref Code": "SD5A432GB-HNR"
      },
      {
        "New Ref Code": "SD5A425GA-HNR"
      },
      {
        "New Ref Code": "SD5A445GB-HNR"
      }
    ]
  },
  "SD5A8": {
    "SD5A8": [
      {
        "New Ref Code": "SD5A825GA-HNR"
      }
    ]
  },
  "SD602": {
    "SD602": [
      {
        "New Ref Code": "SD60230U-HNI"
      },
      {
        "New Ref Code": "SD60225U-HNI"
      },
      {
        "New Ref Code": "SD60230U-HNI-SL"
      }
    ]
  },
  "SD604": {
    "SD604": [
      {
        "New Ref Code": "SD60430U-HNI"
      }
    ]
  },
  "SD6AL": {
    "SD6AL": [
      {
        "New Ref Code": "SD6AL445XA-HNR"
      },
      {
        "New Ref Code": "SD6AL445XA-HNR-IR"
      },
      {
        "New Ref Code": "SD6AL245XA-HNR"
      },
      {
        "New Ref Code": "SD6AL245U-HNI"
      }
    ]
  },
  "SD6C3": {
    "SD6C3": [
      {
        "New Ref Code": "SD6C3432XB-HNR-AGQ-PV"
      },
      {
        "New Ref Code": "SD6C3425XB-HNR-A-PV1"
      }
    ]
  },
  "SD6CE": {
    "SD6CE": [
      {
        "New Ref Code": "SD6CE432GB-HNR"
      },
      {
        "New Ref Code": "SD6CE232GB-HNR"
      },
      {
        "New Ref Code": "SD6CE225DB-HNY"
      },
      {
        "New Ref Code": "SD6CE445GB-HNR"
      },
      {
        "New Ref Code": "SD6CE245GB-HNR"
      }
    ]
  },
  "SD8A3": {
    "SD8A3": [
      {
        "New Ref Code": "SD8A3440GA-HNV"
      }
    ]
  },
  "SD8A4": {
    "SD8A4": [
      {
        "New Ref Code": "SD8A440GA-HNV"
      },
      {
        "New Ref Code": "SD8A440FA-HNT"
      },
      {
        "New Ref Code": "SD8A440PA-HNF-5G"
      },
      {
        "New Ref Code": "SD8A440-HNF-PA"
      }
    ]
  },
  "SD8A8": {
    "SD8A8": [
      {
        "New Ref Code": "SD8A840XA-HNP-WP"
      },
      {
        "New Ref Code": "SD8A840-HNF-PA"
      },
      {
        "New Ref Code": "SD8A840PA-HNF-SL"
      }
    ]
  },
  "SD8C2": {
    "SD8C2": [
      {
        "New Ref Code": "SD8C260PA-HNF"
      },
      {
        "New Ref Code": "SD8C260PA1-HNF"
      }
    ]
  },
  "SD8C4": {
    "SD8C4": [
      {
        "New Ref Code": "SD8C448PA-HNF"
      },
      {
        "New Ref Code": "SD8C448PA1-HNF"
      },
      {
        "New Ref Code": "SD8C440FD-HNF"
      }
    ]
  },
  "SD8C8": {
    "SD8C8": [
      {
        "New Ref Code": "SD8C848PA-HNF"
      },
      {
        "New Ref Code": "SD8C848PA1-HNF"
      },
      {
        "New Ref Code": "SD8C845FG-HNF"
      }
    ]
  },
  "SDPH0": {
    "SDPH0": [
      {
        "New Ref Code": "SDPH004"
      },
      {
        "New Ref Code": "SDPH002"
      }
    ]
  },
  "SDT5X": {
    "SDT5X": [
      {
        "New Ref Code": "SDT5X425-4Z4-QA-2812"
      },
      {
        "New Ref Code": "SDT5X225-2F-QA-0600"
      },
      {
        "New Ref Code": "SDT5X425-4Z4-QA-0832"
      },
      {
        "New Ref Code": "SDT5X425-4Z4-FAJG-PV-0832"
      }
    ]
  },
  "SDT7C": {
    "SDT7C": [
      {
        "New Ref Code": "SDT7C424-4F-ZBZJ-APV-0400"
      }
    ]
  },
  "SDZW2": {
    "SDZW2": [
      {
        "New Ref Code": "SDZW2030U-SL"
      },
      {
        "New Ref Code": "SDZW2000T-SL"
      },
      {
        "New Ref Code": "SDZW2000T-SL"
      }
    ]
  },
  "SF102": {
    "SF102": [
      {
        "New Ref Code": "SF1024"
      }
    ]
  },
  "SG100": {
    "SG100": [
      {
        "New Ref Code": "SG1008P"
      }
    ]
  },
  "SG402": {
    "SG402": [
      {
        "New Ref Code": "SG4028"
      }
    ]
  },
  "TAM01": {
    "TAM01": [
      {
        "New Ref Code": "TAM01GT01GT-75"
      }
    ]
  },
  "TAM1G": {
    "TAM1G": [
      {
        "New Ref Code": "TAM1GT1GT-30"
      }
    ]
  },
  "VTA23": {
    "VTA23": [
      {
        "New Ref Code": "VTA2302A"
      }
    ]
  },
  "VTH10": {
    "VTH10": [
      {
        "New Ref Code": "VTH1010J"
      },
      {
        "New Ref Code": "VTH1020J"
      },
      {
        "New Ref Code": "VTH1020J-T"
      }
    ]
  },
  "VTH15": {
    "VTH15": [
      {
        "New Ref Code": "VTH1521G"
      },
      {
        "New Ref Code": "VTH1550CH-S2"
      }
    ]
  },
  "VTH24": {
    "VTH24": [
      {
        "New Ref Code": "VTH2421FW"
      },
      {
        "New Ref Code": "VTH2421FB"
      },
      {
        "New Ref Code": "VTH2421FW-P"
      },
      {
        "New Ref Code": "VTH2421FB-P"
      }
    ]
  },
  "VTH25": {
    "VTH25": [
      {
        "New Ref Code": "VTH2521G"
      }
    ]
  },
  "VTH26": {
    "VTH26": [
      {
        "New Ref Code": "VTH2611L-WP"
      },
      {
        "New Ref Code": "VTH2621G-P"
      },
      {
        "New Ref Code": "VTH2621GW-P"
      },
      {
        "New Ref Code": "VTH2621G-WP"
      },
      {
        "New Ref Code": "VTH2621GW-WP"
      },
      {
        "New Ref Code": "VTH2622G-W"
      },
      {
        "New Ref Code": "VTH2622GW-W"
      }
    ]
  },
  "VTH51": {
    "VTH51": [
      {
        "New Ref Code": "VTH5123H-W"
      }
    ]
  },
  "VTH52": {
    "VTH52": [
      {
        "New Ref Code": "VTH5221D-S2"
      },
      {
        "New Ref Code": "VTH5221DW-S2"
      },
      {
        "New Ref Code": "VTH5241DW-S2"
      }
    ]
  },
  "VTH53": {
    "VTH53": [
      {
        "New Ref Code": "VTH5321GW-W"
      },
      {
        "New Ref Code": "VTH5321GB-W"
      },
      {
        "New Ref Code": "VTH5341G-W"
      }
    ]
  },
  "VTH54": {
    "VTH54": [
      {
        "New Ref Code": "VTH5421HB-W"
      },
      {
        "New Ref Code": "VTH5421HW-W"
      },
      {
        "New Ref Code": "VTH5422HW-W"
      },
      {
        "New Ref Code": "VTH5422HB-W"
      },
      {
        "New Ref Code": "VTH5422HW"
      },
      {
        "New Ref Code": "VTH5422HB"
      },
      {
        "New Ref Code": "VTH5421HW"
      },
      {
        "New Ref Code": "VTH5421HB"
      },
      {
        "New Ref Code": "VTH5421E-H"
      },
      {
        "New Ref Code": "VTH5421EW-H"
      },
      {
        "New Ref Code": "VTH5441G"
      }
    ]
  },
  "VTH86": {
    "VTH86": [
      {
        "New Ref Code": "VTH8621KMS-WP"
      },
      {
        "New Ref Code": "VTH8622KMS-W"
      },
      {
        "New Ref Code": "VTH8641KMS-WP"
      },
      {
        "New Ref Code": "VTH8642KMS-W"
      }
    ]
  },
  "VTH8A": {
    "VTH8A": [
      {
        "New Ref Code": "VTH8A21KMS-W"
      },
      {
        "New Ref Code": "VTH8A41KMS-W"
      },
      {
        "New Ref Code": "VTH8A21KMS-CW"
      }
    ]
  },
  "VTM12": {
    "VTM12": [
      {
        "New Ref Code": "VTM123"
      }
    ]
  },
  "VTM41": {
    "VTM41": [
      {
        "New Ref Code": "VTM416"
      }
    ]
  },
  "VTM50": {
    "VTM50": [
      {
        "New Ref Code": "VTM50B1"
      },
      {
        "New Ref Code": "VTM502"
      },
      {
        "New Ref Code": "VTM503"
      }
    ]
  },
  "VTM57": {
    "VTM57": [
      {
        "New Ref Code": "VTM57"
      }
    ]
  },
  "VTM58": {
    "VTM58": [
      {
        "New Ref Code": "VTM58"
      }
    ]
  },
  "VTNS1": {
    "VTNS1": [
      {
        "New Ref Code": "VTNS1001B-2"
      }
    ]
  },
  "VTNS2": {
    "VTNS2": [
      {
        "New Ref Code": "VTNS2003B-2"
      }
    ]
  },
  "VTO03": {
    "VTO03": [
      {
        "New Ref Code": "VTO0301R-W"
      }
    ]
  },
  "VTO10": {
    "VTO10": [
      {
        "New Ref Code": "VTO1000JM"
      },
      {
        "New Ref Code": "VTO1000J"
      }
    ]
  },
  "VTO11": {
    "VTO11": [
      {
        "New Ref Code": "VTO1101D-P"
      }
    ]
  },
  "VTO12": {
    "VTO12": [
      {
        "New Ref Code": "VTO1201G-P"
      }
    ]
  },
  "VTO13": {
    "VTO13": [
      {
        "New Ref Code": "VTO1301R-W"
      }
    ]
  },
  "VTO20": {
    "VTO20": [
      {
        "New Ref Code": "VTO2003F"
      }
    ]
  },
  "VTO21": {
    "VTO21": [
      {
        "New Ref Code": "VTO2101X-PW"
      },
      {
        "New Ref Code": "VTO2101E-P-S2"
      },
      {
        "New Ref Code": "VTO2111D-P-S2"
      }
    ]
  },
  "VTO22": {
    "VTO22": [
      {
        "New Ref Code": "VTO2202F-P-S2"
      },
      {
        "New Ref Code": "VTO2201F-P"
      },
      {
        "New Ref Code": "VTO2202F-P"
      },
      {
        "New Ref Code": "VTO2211G-WP"
      },
      {
        "New Ref Code": "VTO2211G-P"
      }
    ]
  },
  "VTO23": {
    "VTO23": [
      {
        "New Ref Code": "VTO2311R-WP"
      }
    ]
  },
  "VTO32": {
    "VTO32": [
      {
        "New Ref Code": "VTO3221E-P"
      },
      {
        "New Ref Code": "VTO3211D-P1-S2"
      },
      {
        "New Ref Code": "VTO3211D-P2-S2"
      },
      {
        "New Ref Code": "VTO3211D-P4-S2"
      }
    ]
  },
  "VTO33": {
    "VTO33": [
      {
        "New Ref Code": "VTO3312Q-P"
      }
    ]
  },
  "VTO42": {
    "VTO42": [
      {
        "New Ref Code": "VTO4202F-P"
      },
      {
        "New Ref Code": "VTO4202F-P-S2"
      },
      {
        "New Ref Code": "VTO4202FB-P-S2"
      },
      {
        "New Ref Code": "VTO4202F-MB1"
      },
      {
        "New Ref Code": "VTO4202F-MB2"
      },
      {
        "New Ref Code": "VTO4202F-MB5"
      },
      {
        "New Ref Code": "VTO4202F-MK"
      },
      {
        "New Ref Code": "VTO4202F-MF"
      },
      {
        "New Ref Code": "VTO4202F-ML"
      },
      {
        "New Ref Code": "VTO4202F-MS"
      },
      {
        "New Ref Code": "VTO4202F-MR"
      },
      {
        "New Ref Code": "VTO4202F-MN"
      },
      {
        "New Ref Code": "VTO4202F-MR1"
      },
      {
        "New Ref Code": "VTO4202FB-MB1"
      },
      {
        "New Ref Code": "VTO4202FB-MB2"
      },
      {
        "New Ref Code": "VTO4202FB-MB5"
      },
      {
        "New Ref Code": "VTO4202FB-MF"
      },
      {
        "New Ref Code": "VTO4202FB-MK"
      },
      {
        "New Ref Code": "VTO4202FB-ML"
      },
      {
        "New Ref Code": "VTO4202FB-MN"
      },
      {
        "New Ref Code": "VTO4202FB-MR"
      },
      {
        "New Ref Code": "VTO4202FB-MS"
      },
      {
        "New Ref Code": "VTO4202FB-MR1"
      }
    ]
  },
  "VTO62": {
    "VTO62": [
      {
        "New Ref Code": "VTO6221E-P"
      }
    ]
  },
  "VTO65": {
    "VTO65": [
      {
        "New Ref Code": "VTO6521K"
      },
      {
        "New Ref Code": "VTO6521F"
      },
      {
        "New Ref Code": "VTO6541H"
      },
      {
        "New Ref Code": "VTO6531H"
      },
      {
        "New Ref Code": "VTO6521H"
      },
      {
        "New Ref Code": "VTO6521H-D"
      }
    ]
  },
  "VTO75": {
    "VTO75": [
      {
        "New Ref Code": "VTO7541G"
      },
      {
        "New Ref Code": "VTO7521G"
      }
    ]
  },
  "VTO95": {
    "VTO95": [
      {
        "New Ref Code": "VTO9541D"
      }
    ]
  },
  "W-HDM": {
    "W-HDM": [
      {
        "New Ref Code": "W-HDMI15M"
      },
      {
        "New Ref Code": "W-HDMI10M-4K"
      },
      {
        "New Ref Code": "W-HDMI10M"
      }
    ]
  },
  "XVR1B": {
    "XVR1B": [
      {
        "New Ref Code": "XVR1B08H-I"
      },
      {
        "New Ref Code": "XVR1B16-I"
      },
      {
        "New Ref Code": "XVR1B04-I"
      },
      {
        "New Ref Code": "XVR1B08-I"
      },
      {
        "New Ref Code": "XVR1B04-I"
      },
      {
        "New Ref Code": "XVR1B04H-I"
      },
      {
        "New Ref Code": "XVR1B08-I"
      },
      {
        "New Ref Code": "XVR1B04-I"
      },
      {
        "New Ref Code": "XVR1B04H-I"
      },
      {
        "New Ref Code": "XVR1B08-I"
      },
      {
        "New Ref Code": "XVR1B08H-I"
      },
      {
        "New Ref Code": "XVR1B16-I"
      },
      {
        "New Ref Code": "XVR1B16-I"
      },
      {
        "New Ref Code": "XVR1B08H-I"
      },
      {
        "New Ref Code": "XVR1B16H-I"
      }
    ]
  },
  "XVR41": {
    "XVR41": [
      {
        "New Ref Code": "XVR4116HS-I"
      }
    ]
  },
  "XVR42": {
    "XVR42": [
      {
        "New Ref Code": "XVR4232AN-I"
      }
    ]
  },
  "XVR51": {
    "XVR51": [
      {
        "New Ref Code": "XVR5116H-4KL-I3"
      },
      {
        "New Ref Code": "XVR5108HS-4KL-I3"
      },
      {
        "New Ref Code": "XVR5108H-4KL-I3"
      },
      {
        "New Ref Code": "XVR5108HE-4KL-I3"
      },
      {
        "New Ref Code": "XVR5116HE-4KL-I3"
      },
      {
        "New Ref Code": "XVR5108H-4KL-I3-8P"
      },
      {
        "New Ref Code": "XVR5108H-I3-8P"
      },
      {
        "New Ref Code": "XVR5104H-4KL-I3-4P"
      },
      {
        "New Ref Code": "XVR5104H-I3-4P"
      },
      {
        "New Ref Code": "XVR5108C-I3"
      },
      {
        "New Ref Code": "XVR5108HS-I3"
      },
      {
        "New Ref Code": "XVR5108H-I3"
      },
      {
        "New Ref Code": "XVR5108HE-I3"
      },
      {
        "New Ref Code": "XVR5104C-4KL-I3"
      },
      {
        "New Ref Code": "XVR5104HS-4KL-I3"
      },
      {
        "New Ref Code": "XVR5104H-4KL-I3"
      },
      {
        "New Ref Code": "XVR5104HE-4KL-I3"
      },
      {
        "New Ref Code": "XVR5104HS-I3"
      },
      {
        "New Ref Code": "XVR5104H-I3"
      },
      {
        "New Ref Code": "XVR5108HS-I3"
      },
      {
        "New Ref Code": "XVR5116HS-I3"
      },
      {
        "New Ref Code": "XVR5116H-I3"
      },
      {
        "New Ref Code": "XVR5108HE-I3"
      },
      {
        "New Ref Code": "XVR5116HE-I3"
      },
      {
        "New Ref Code": "XVR5104HS-4KL-I3"
      }
    ]
  },
  "XVR52": {
    "XVR52": [
      {
        "New Ref Code": "XVR5232AN-I3"
      },
      {
        "New Ref Code": "XVR5232AN-4KL-I3"
      },
      {
        "New Ref Code": "XVR5208AN-4KL-I3"
      },
      {
        "New Ref Code": "XVR5208A-4KL-I3"
      },
      {
        "New Ref Code": "XVR5216AN-4KL-I3"
      },
      {
        "New Ref Code": "XVR5216A-4KL-I3"
      },
      {
        "New Ref Code": "XVR5216AN-4KL-I3-16P"
      },
      {
        "New Ref Code": "XVR5208AN-4KL-I3-8P"
      },
      {
        "New Ref Code": "XVR5216AN-I3-16P"
      },
      {
        "New Ref Code": "XVR5216A-I3"
      },
      {
        "New Ref Code": "XVR5216AN-I3"
      },
      {
        "New Ref Code": "XVR5208A-4KL-I3"
      },
      {
        "New Ref Code": "XVR5216AN-4KL-I3"
      }
    ]
  },
  "XVR54": {
    "XVR54": [
      {
        "New Ref Code": "XVR5432L-I3"
      },
      {
        "New Ref Code": "XVR5416L-4KL-I3"
      },
      {
        "New Ref Code": "XVR5432L-4KL-I3"
      },
      {
        "New Ref Code": "XVR5416L-I3"
      }
    ]
  },
  "XVR58": {
    "XVR58": [
      {
        "New Ref Code": "XVR5832S-I3"
      },
      {
        "New Ref Code": "XVR5816S-4KL-I3"
      },
      {
        "New Ref Code": "XVR5832S-4KL-I3"
      },
      {
        "New Ref Code": "XVR5816S-4KL-I3-LP"
      },
      {
        "New Ref Code": "XVR5816S-I3"
      }
    ]
  },
  "XVR71": {
    "XVR71": [
      {
        "New Ref Code": "XVR7108H-4K-I3"
      },
      {
        "New Ref Code": "XVR7108HE-4K-I3"
      },
      {
        "New Ref Code": "XVR7104H-4K-I3"
      },
      {
        "New Ref Code": "XVR7104HE-4K-I3"
      }
    ]
  },
  "XVR72": {
    "XVR72": [
      {
        "New Ref Code": "XVR7208A-4K-I3"
      },
      {
        "New Ref Code": "XVR7216AN-4K-I3"
      }
    ]
  },
  "XVR74": {
    "XVR74": [
      {
        "New Ref Code": "XVR7416L-4K-I3"
      },
      {
        "New Ref Code": "XVR7408L-4K-I3"
      }
    ]
  },
  "XVR78": {
    "XVR78": [
      {
        "New Ref Code": "XVR7816S-4K-I3"
      },
      {
        "New Ref Code": "XVR7808S-4K-I3"
      }
    ]
  },
  "YJ104": {
    "YJ104": [
      {
        "New Ref Code": "YJ104"
      }
    ]
  },
  "ZAZ10": {
    "ZAZ10": [
      {
        "New Ref Code": "ZAZ100W"
      }
    ]
  }
}

# %%
# Iterate over group_data_hyphens and check product existence
for category, subcategories in group_data_hyphens.items():
    for subcategory, ref_codes_list in subcategories.items():
        for ref_code_entry in ref_codes_list:
            ref_code = ref_code_entry["New Ref Code"]
            
            product_exists = env['product.template'].search_count([('default_code', '=', ref_code)])

            if product_exists:
                print(f"Product with ref code {ref_code} exists in {category}/{subcategory}.")
            else:
                print(f"No product found for ref code {ref_code} in {category}/{subcategory}.")
# Out:
# No product found for ref code ART-ARC3000H-03-FW2(868) in ART/ART-A.
# No product found for ref code ART-ARC3000H-03-GW2(868) in ART/ART-A.
# No product found for ref code ART-ARC3000H-03-W2(868) in ART/ART-A.
# No product found for ref code CSS-CSM in CSS/CSS-C.
# No product found for ref code CSS-TPCN in CSS/CSS-T.
# No product found for ref code DAE-CBS5210-H-CYN in DAE/DAE-C.
# No product found for ref code DAE-CBS5210-H-CYP in DAE/DAE-C.
# No product found for ref code DAE-CBS5210-V-CYP in DAE/DAE-C.
# No product found for ref code DAE-CBS5210-V-CYN in DAE/DAE-C.
# No product found for ref code DAE-CDR8213-GFW in DAE/DAE-C.
# No product found for ref code DDR-C300S16G32 in DDR/DDR-C.
# No product found for ref code DDR-C300S4G26 in DDR/DDR-C.
# No product found for ref code DDR-C300U8G26 in DDR/DDR-C.
# No product found for ref code DDR-C300S8G26 in DDR/DDR-C.
# No product found for ref code DDR-C300U16G26 in DDR/DDR-C.
# ...

# %%
# Iterate over group_data_hyphens and check product existence
existing_products = []
non_existing_products = []

for category, subcategories in group_data_without_hyphen.items():
    for subcategory, ref_codes_list in subcategories.items():
        for ref_code_entry in ref_codes_list:
            ref_code = ref_code_entry["New Ref Code"]
            
            product_exists = env['product.template'].search_count([('default_code', '=', ref_code)])
            
            if product_exists:
                existing_products.append({
                    'ref_code': ref_code,
                    'category': category,
                    'subcategory': subcategory,
                })
            else:
                non_existing_products.append({
                    'ref_code': ref_code,
                    'category': category,
                    'subcategory': subcategory,
                })

# Print or use the lists of existing and non-existing products
print("Existing Products:")
for product in existing_products:
    print(f"Ref Code: {product['ref_code']}, Category: {product['category']}, Subcategory: {product['subcategory']}")
print("--------------------------------------------------------------------------------------------------------------")
print(len(existing_products))
print("\nNon-Existing Products:")
for product in non_existing_products:
    print(f"Ref Code: {product['ref_code']}, Category: {product['category']}, Subcategory: {product['subcategory']}")
# Out:
# Existing Products:
# Ref Code: DSS4004-S2, Category: DSS40, Subcategory: DSS40
# Ref Code: EPC245U-PTZ-IR, Category: EPC24, Subcategory: EPC24
# Ref Code: NVD0405DU-2I-8K, Category: NVD04, Subcategory: NVD04
# Ref Code: PFA100, Category: PFA10, Subcategory: PFA10
# Ref Code: PFA101, Category: PFA10, Subcategory: PFA10
# Ref Code: PFA102, Category: PFA10, Subcategory: PFA10
# Ref Code: PFA105, Category: PFA10, Subcategory: PFA10
# Ref Code: PFA106, Category: PFA10, Subcategory: PFA10
# Ref Code: PFA112, Category: PFA11, Subcategory: PFA11
# Ref Code: PFA113, Category: PFA11, Subcategory: PFA11
# Ref Code: PFA117, Category: PFA11, Subcategory: PFA11
# Ref Code: PFA120, Category: PFA12, Subcategory: PFA12
# Ref Code: PFA130-E, Category: PFA13, Subcategory: PFA13
# Ref Code: PFA132-E, Category: PFA13, Subcategory: PFA13
# Ref Code: PFA134, Category: PFA13, Subcategory: PFA13
# Ref Code: PFA135, Category: PFA13, Subcategory: PFA13
# Ref Code: PFA136, Category: PFA13, Subcategory: PFA13
# ...

# %%
# Lists to store products that exist, don't exist, and middle correspondences
existing_products = []
non_existing_products = []
mid_correspond = []

# Iterate over group_data_hyphens and check product existence
for category, subcategories in group_data_hyphens.items():
    for subcategory, ref_codes_list in subcategories.items():
        for ref_code_entry in ref_codes_list:
            ref_code = ref_code_entry["New Ref Code"]
            
            # Attempt 1: Try with the original ref_code
            print(f"Trying with the entire ref_code: {ref_code}")
            products = env['product.template'].search([('default_code', '=', ref_code)])
            if products:
                for product in products:
                    print(f"   Found with default_code: {product.default_code}")
                existing_products.append({
                    'ref_code': ref_code,
                    'category': category,
                    'subcategory': subcategory,
                    'products': [product.default_code for product in products],
                })
            
            # Attempt 2: Try with the middle part of the ref_code
            if not products:
                parts = ref_code.split('-')
                if len(parts) >= 3 and parts[1]:
                    middle_part = '-'.join(parts[1:-1])
                    print(f"Trying with the middle part: {middle_part}")
                    products = env['product.template'].search([('default_code', '=', middle_part)])
                    if products:
                        for product in products:
                            print(f"   Found with default_code: {product.default_code}")
                        mid_correspond.append({
                            'ref_code': ref_code,
                            'category': category,
                            'subcategory': subcategory,
                            'middle_part': middle_part,
                            'products': [product.default_code for product in products],
                        })

            # Attempt 3: Try with the middle and last part
            if not products:
                if len(parts) >= 3 and parts[1]:
                    middle_last_part = '-'.join(parts[1:])
                    print(f"Trying with the middle and last part: {middle_last_part}")
                    products = env['product.template'].search([('default_code', '=', middle_last_part)])
                    if products:
                        for product in products:
                            print(f"   Found with default_code: {product.default_code}")
                        existing_products.append({
                            'ref_code': ref_code,
                            'category': category,
                            'subcategory': subcategory,
                            'products': [product.default_code for product in products],
                        })

# Print or use the lists of existing, non-existing products, and middle correspondences
print("Existing Products:")
for product_info in existing_products:
    print(f"Ref Code: {product_info['ref_code']}, Category: {product_info['category']}, Subcategory: {product_info['subcategory']}")
    for default_code in product_info['products']:
        print(f"   Found with default_code: {default_code}")

print("\nMiddle Correspondences:")
for mid_info in mid_correspond:
    print(f"Ref Code: {mid_info['ref_code']}, Category: {mid_info['category']}, Subcategory: {mid_info['subcategory']}, Middle Part: {mid_info['middle_part']}")
    for default_code in mid_info['products']:
        print(f"   Found with default_code: {default_code}")
# Out:
# Trying with the entire ref_code: ART-ARC3000H-03-FW2(868)
# Trying with the middle part: ARC3000H-03
# Trying with the middle and last part: ARC3000H-03-FW2(868)
# Trying with the entire ref_code: ART-ARC3000H-03-GW2(868)
# Trying with the middle part: ARC3000H-03
# Trying with the middle and last part: ARC3000H-03-GW2(868)
# Trying with the entire ref_code: ART-ARC3000H-03-W2(868)
# Trying with the middle part: ARC3000H-03
# Trying with the middle and last part: ARC3000H-03-W2(868)
# Trying with the entire ref_code: CSS-CSM
# Trying with the entire ref_code: CSS-TPCN
# Trying with the entire ref_code: DAE-CBS5210-H-CYN
# Trying with the middle part: CBS5210-H
# Trying with the middle and last part: CBS5210-H-CYN
# Trying with the entire ref_code: DAE-CBS5210-H-CYP
# Trying with the middle part: CBS5210-H
# Trying with the middle and last part: CBS5210-H-CYP
# Trying with the entire ref_code: DAE-CBS5210-V-CYP
# Trying with the middle part: CBS5210-V
# ...

# %%
# Iterate over group_data_hyphens and check product existence
for category, subcategories in group_data_hyphens.items():
    for subcategory, ref_codes_list in subcategories.items():
        for ref_code_entry in ref_codes_list:
            ref_code = ref_code_entry["New Ref Code"]
            
            # Attempt 1: Try with the original ref_code
            print(f"Trying with the entire ref_code: {ref_code}")
            products = env['product.template'].search([('default_code', '=', ref_code)])
            if products:
                for product in products:
                    print(f"Found with default_code: {product.default_code}")

            # Attempt 2: Try with the middle part of the ref_code
            if not products:
                parts = ref_code.split('-')
                if len(parts) >= 3 and parts[1]:
                    middle_part = '-'.join(parts[1:-1])
                    print(f"Trying with the middle part: {middle_part}")
                    products = env['product.template'].search([('default_code', '=', middle_part)])
                    if products:
                        for product in products:
                            print(f"Found with default_code: {product.default_code}")

            # Attempt 3: Try with the middle and last part
            if not products:
                if len(parts) >= 3 and parts[1]:
                    middle_last_part = '-'.join(parts[1:])
                    print(f"Trying with the middle and last part: {middle_last_part}")
                    products = env['product.template'].search([('default_code', '=', middle_last_part)])
                    if products:
                        for product in products:
                            print(f"Found with default_code: {product.default_code}")

            if products:
                existing_products.append({
                    'ref_code': ref_code,
                    'category': category,
                    'subcategory': subcategory,
                    'products': [product.default_code for product in products]
                })
            else:
                non_existing_products.append({
                    'ref_code': ref_code,
                    'category': category,
                    'subcategory': subcategory,
                })

# Print or use the lists of existing and non-existing products
print("Existing Products:")
for product_info in existing_products:
    print(f"Ref Code: {product_info['ref_code']}, Category: {product_info['category']}, Subcategory: {product_info['subcategory']}, Found with default_code: {default_code}")
# Out:
# Trying with the entire ref_code: ART-ARC3000H-03-FW2(868)
# Trying with the middle part: ARC3000H-03
# Trying with the middle and last part: ARC3000H-03-FW2(868)
# Trying with the entire ref_code: ART-ARC3000H-03-GW2(868)
# Trying with the middle part: ARC3000H-03
# Trying with the middle and last part: ARC3000H-03-GW2(868)
# Trying with the entire ref_code: ART-ARC3000H-03-W2(868)
# Trying with the middle part: ARC3000H-03
# Trying with the middle and last part: ARC3000H-03-W2(868)
# Trying with the entire ref_code: CSS-CSM
# Trying with the entire ref_code: CSS-TPCN
# Trying with the entire ref_code: DAE-CBS5210-H-CYN
# Trying with the middle part: CBS5210-H
# Trying with the middle and last part: CBS5210-H-CYN
# Trying with the entire ref_code: DAE-CBS5210-H-CYP
# Trying with the middle part: CBS5210-H
# Trying with the middle and last part: CBS5210-H-CYP
# Trying with the entire ref_code: DAE-CBS5210-V-CYP
# Trying with the middle part: CBS5210-V
# ...

# %%
# Iterate over group_data_hyphens and check product existence
for category, subcategories in group_data_hyphens.items():
    for subcategory, ref_codes_list in subcategories.items():
        for ref_code_entry in ref_codes_list:
            ref_code = ref_code_entry["New Ref Code"]
            
            # Attempt 1: Try with the original ref_code
            print(f"Trying with the entire ref_code: {ref_code}")
            products = env['product.template'].search([('default_code', '=', ref_code)])
            if products:
                for product in products:
                    print(f"   Found with default_code: {product.default_code}")
                existing_products.append({
                    'ref_code': ref_code,
                    'category': category,
                    'subcategory': subcategory,
                    'products': [product.default_code for product in products],
                })
            
            # Attempt 2: Try with the middle part of the ref_code
            if not products:
                parts = ref_code.split('-')
                if len(parts) >= 3 and parts[1]:
                    middle_part = '-'.join(parts[1:-1])
                    print(f"Trying with the middle part: {middle_part}")
                    products = env['product.template'].search([('default_code', '=', middle_part)])
                    if products:
                        for product in products:
                            print(f"   Found with default_code: {product.default_code}")
                        mid_correspond.append({
                            'ref_code': ref_code,
                            'category': category,
                            'subcategory': subcategory,
                            'middle_part': middle_part,
                            'products': [product.default_code for product in products],
                        })

            # Attempt 3: Try with the middle and last part
            if not products:
                if len(parts) >= 3 and parts[1]:
                    middle_last_part = '-'.join(parts[1:])
                    print(f"Trying with the middle and last part: {middle_last_part}")
                    products = env['product.template'].search([('default_code', '=', middle_last_part)])
                    if products:
                        for product in products:
                            print(f"   Found with default_code: {product.default_code}")
                        existing_products.append({
                            'ref_code': ref_code,
                            'category': category,
                            'subcategory': subcategory,
                            'products': [product.default_code for product in products],
                        })

# Print or use the lists of existing, non-existing products, and middle correspondences
print("Existing Products:")
for product_info in existing_products:
    print(f"Ref Code: {product_info['ref_code']}, Category: {product_info['category']}, Subcategory: {product_info['subcategory']}")
    for default_code in product_info['products']:
        print(f"   Found with default_code: {default_code}")

print("\nMiddle Correspondences:")
for mid_info in mid_correspond:
    print(f"Ref Code: {mid_info['ref_code']}, Category: {mid_info['category']}, Subcategory: {mid_info['subcategory']}, Middle Part: {mid_info['middle_part']}")
    for default_code in mid_info['products']:
        print(f"   Found with default_code: {default_code}")
# Out:
# Trying with the entire ref_code: ART-ARC3000H-03-FW2(868)
# Trying with the middle part: ARC3000H-03
# Trying with the middle and last part: ARC3000H-03-FW2(868)
# Trying with the entire ref_code: ART-ARC3000H-03-GW2(868)
# Trying with the middle part: ARC3000H-03
# Trying with the middle and last part: ARC3000H-03-GW2(868)
# Trying with the entire ref_code: ART-ARC3000H-03-W2(868)
# Trying with the middle part: ARC3000H-03
# Trying with the middle and last part: ARC3000H-03-W2(868)
# Trying with the entire ref_code: CSS-CSM
# Trying with the entire ref_code: CSS-TPCN
# Trying with the entire ref_code: DAE-CBS5210-H-CYN
# Trying with the middle part: CBS5210-H
# Trying with the middle and last part: CBS5210-H-CYN
# Trying with the entire ref_code: DAE-CBS5210-H-CYP
# Trying with the middle part: CBS5210-H
# Trying with the middle and last part: CBS5210-H-CYP
# Trying with the entire ref_code: DAE-CBS5210-V-CYP
# Trying with the middle part: CBS5210-V
# ...

# %%
# Iterate over group_data_hyphens and check product existence
for category, subcategories in group_data_without_hyphen.items():
    for subcategory, ref_codes_list in subcategories.items():
        for ref_code_entry in ref_codes_list:
            ref_code = ref_code_entry["New Ref Code"]
            
            # Attempt 1: Try with the original ref_code
            print(f"Trying with the entire ref_code: {ref_code}")
            products = env['product.template'].search([('default_code', '=', ref_code)])
            if products:
                for product in products:
                    print(f"   Found with default_code: {product.default_code}")
                existing_products.append({
                    'ref_code': ref_code,
                    'category': category,
                    'subcategory': subcategory,
                    'products': [product.default_code for product in products],
                })
            
            # Attempt 2: Try with the middle part of the ref_code
            if not products:
                parts = ref_code.split('-')
                if len(parts) >= 3 and parts[1]:
                    middle_part = '-'.join(parts[1:-1])
                    print(f"Trying with the middle part: {middle_part}")
                    products = env['product.template'].search([('default_code', '=', middle_part)])
                    if products:
                        for product in products:
                            print(f"   Found with default_code: {product.default_code}")
                        mid_correspond.append({
                            'ref_code': ref_code,
                            'category': category,
                            'subcategory': subcategory,
                            'middle_part': middle_part,
                            'products': [product.default_code for product in products],
                        })

            # Attempt 3: Try with the middle and last part
            if not products:
                if len(parts) >= 3 and parts[1]:
                    middle_last_part = '-'.join(parts[1:])
                    print(f"Trying with the middle and last part: {middle_last_part}")
                    products = env['product.template'].search([('default_code', '=', middle_last_part)])
                    if products:
                        for product in products:
                            print(f"   Found with default_code: {product.default_code}")
                        existing_products.append({
                            'ref_code': ref_code,
                            'category': category,
                            'subcategory': subcategory,
                            'products': [product.default_code for product in products],
                        })

# Print or use the lists of existing, non-existing products, and middle correspondences
print("Existing Products:")
for product_info in existing_products:
    print(f"Ref Code: {product_info['ref_code']}, Category: {product_info['category']}, Subcategory: {product_info['subcategory']}")
    for default_code in product_info['products']:
        print(f"   Found with default_code: {default_code}")

print("\nMiddle Correspondences:")
for mid_info in mid_correspond:
    print(f"Ref Code: {mid_info['ref_code']}, Category: {mid_info['category']}, Subcategory: {mid_info['subcategory']}, Middle Part: {mid_info['middle_part']}")
    for default_code in mid_info['products']:
        print(f"   Found with default_code: {default_code}")
# Out:
# Trying with the entire ref_code: 8019
# Trying with the entire ref_code: AC12
# Trying with the entire ref_code: AR306-E
# Trying with the entire ref_code: AR506-E
# Trying with the entire ref_code: ARA12-W2(868)
# Trying with the entire ref_code: ARA13-W2(868)
# Trying with the entire ref_code: ARA13-W2(868)
# Trying with the entire ref_code: ARA13-W2(868)
# Trying with the entire ref_code: ARA24-W2(868)
# Trying with the entire ref_code: ARA43-W2(868)
# Trying with the entire ref_code: ARC2016C-V3
# Trying with the entire ref_code: ARC2008C-V3
# Trying with the entire ref_code: ARC3000H-FW2(868)
# Trying with the entire ref_code: ARC3000H-W2(868)
# Trying with the entire ref_code: ARC3008C
# Trying with the entire ref_code: ARC9016C-V3
# Trying with the entire ref_code: ARD1233-W2(868)
# Trying with the entire ref_code: ARD1731-W2(868)
# Trying with the entire ref_code: ARD2231-W2(868)
# Trying with the entire ref_code: ARD324-W2(868S)
# ...
